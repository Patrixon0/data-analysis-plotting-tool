# %%
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⢀⡔⣻⠁⠀⢀⣀⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⢀⣾⠳⢶⣦⠤⣀⠀⠀⠀⠀⠀⠀⠀⣾⢀⡇⡴⠋⣀⠴⣊⣩⣤⠶⠞⢹⣄⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⠀⢠⠈⠙⠢⣙⠲⢤⠤⠤⠀⠒⠳⡄⣿⢀⠾⠓⢋⠅⠛⠉⠉⠝⠀⠼⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⢰⡀⠁⠀⠀⠈⠑⠦⡀⠀⠀⠀⠀⠈⠺⢿⣂⠀⠉⠐⠲⡤⣄⢉⠝⢸⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⢀⡹⠆⠀⠀⠀⠀⡠⠃⠀⠀⠀⠀⠀⠀⠀⠉⠙⠲⣄⠀⠀⠙⣷⡄⢸⠀⠀⠀
#⠀⠀⠀⠀⢸⡀⠙⠂⢠⠀⠀⡠⠊⠀⠀⠀⠀⢠⠀⠀⠀⠀⠘⠄⠀⠀⠑⢦⣔⠀⢡⡸⠀⠀⠀
#⠀⠀⠀⠀⢀⣧⠀⢀⡧⣴⠯⡀⠀⠀⠀⠀⠀⡎⠀⠀⠀⠀⠀⢸⡠⠔⠈⠁⠙⡗⡤⣷⡀⠀⠀
#⠀⠀⠀⠀⡜⠈⠚⠁⣬⠓⠒⢼⠅⠀⠀⠀⣠⡇⠀⠀⠀⠀⠀⠀⣧⠀⠀⠀⡀⢹⠀⠸⡄⠀⠀
#⠀⠀⠀⡸⠀⠀⠀⠘⢸⢀⠐⢃⠀⠀⠀⡰⠋⡇⠀⠀⠀⢠⠀⠀⡿⣆⠀⠀⣧⡈⡇⠆⢻⠀⠀
#⠀⠀⢰⠃⠀⠀⢀⡇⠼⠉⠀⢸⡤⠤⣶⡖⠒⠺⢄⡀⢀⠎⡆⣸⣥⠬⠧⢴⣿⠉⠸⡀⣇⠀
#⠀⠀⠇⠀⠀⠀⢸⠀⠀⠀⣰⠋⠀⢸⣿⣿⠀⠀⠀⠙⢧⡴⢹⣿⣿⠀⠀⠀⠈⣆⠀⠀⢧⢹⡄
#⠀⣸⠀⢠⠀⠀⢸⡀⠀⠀⢻⡀⠀⢸⣿⣿⠀⠀⠀⠀⡼⣇⢸⣿⣿⠀⠀⠀⢀⠏⠀⠀⢸⠀⠇
#⠀⠓⠈⢃⠀⠀⠀⡇⠀⠀⠀⣗⠦⣀⣿⡇⠀⣀⠤⠊⠀⠈⠺⢿⣃⣀⠤⠔⢸⠀⠀⠀⣼⠑⢼
#⠀⠀⠀⢸⡀⣀⣾⣷⡀⠀⢸⣯⣦⡀⠀⠀⠀⢇⣀⣀⠐⠦⣀⠘⠀⠀⢀⣰⣿⣄⠀⠀⡟⠀⠀
#⠀⠀⠀⠀⠛⠁⣿⣿⣧⠀⣿⣿⣿⣿⣦⣀⠀⠀⠀⠀⠀⠀⠀⣀⣠⣴⣿⣿⡿⠈⠢⣼⡇⠀⠀
#⠀⠀⠀⠀⠀⠀⠈⠁⠈⠻⠈⢻⡿⠉⣿⠿⠛⡇⠒⠒⢲⠺⢿⣿⣿⠉⠻⡿⠁⠀⠀⠈⠁⠀⠀
#⢀⠤⠒⠦⡀⠀⠀⠀⠀⠀⠀⠀⢀⠞⠉⠆⠀⠀⠉⠉⠉⠀⠀⡝⣍⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⡎⠀⠀⠀⡇⠀⠀⠀⠀⠀⠀⡰⠋⠀⠀⢸⠀⠀⠀⠀⠀⠀⠀⢡⠈⢦⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⡇⠀⠀⠸⠁⠀⠀⠀⠀⢀⠜⠁⠀⠀⠀⡸⠀⠀⠀⠀⠀⠀⠀⠘⡄⠈⢳⡀⠀⠀⠀⠀⠀⠀⠀
#⡇⠀⠀⢠⠀⠀⠀⠀⠠⣯⣀⠀⠀⠀⡰⡇⠀⠀⠀⠀⠀⠀⠀⠀⢣⠀⢀⡦⠤⢄⡀⠀⠀⠀⠀
#⢱⡀⠀⠈⠳⢤⣠⠖⠋⠛⠛⢷⣄⢠⣷⠁⠀⠀⠀⠀⠀⠀⠀⠀⠘⡾⢳⠃⠀⠘⢇⠀⠀⠀
#⠀⠙⢦⡀⠀⢠⠁⠀⠀⠀⠀⠀⠙⣿⣏⣀⠀⠀⠀⠀⠀⠀⠀⣀⣴⣧⡃⠀⠀⠀ ⠀⣸⠀⠀⠀
#⠀⠀⠀⠈⠉⢺⣄⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣗⣤⣀⣠⡾⠃⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠣⢅⡤⣀⣀⣠⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⠉⠉⠉⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⠉⠁⠀⠉⣿⣿⣿⣿⣿⡿⠻⣿⣿⣿⣿⠛⠉⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⣿⣿⣿⠀⠀⠀⠀⣿⣿⣿⡿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⣿⣿⣿⣟⠀⠀⢠⣿⣿⣿⣿⣧⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⣿⣿⣿⣿⣿⠀⠀⢸⣿⣿⣿⣿⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⡏⠀⠀⢸⣿⣿⣿⣿⣿⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⣿⣿⣿⠀⠀⠀⢺⣿⣿⣿⣿⣿⣿⣷⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⠀⠀⠀⠀⠈⠉⠻⣿⣿⣿⠟⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⢿⣿⣿⣿⠏⠀⠀⠀⠀⠀⠀⠀⠀
# 


import sys
import os
import sympy as sp
import numpy as np

# Add the correct path to the P2 folder
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

from gauss_fehlerfortpflanzung import evaluate_gaussian_error
from geraden_fit import geraden_fit
from scientific_error_rounder import runden_und_speichern
from mean_calc_w_err import err_weighted_mean
from data_handler import add_column_to_file

# %% [markdown]
# # 372.a

# %%
from geraden_fit_config import config_1 as config  # Importiert die Config-Datei

# Funktion mit den Werten aus config.py aufrufen
geraden_fit(
    file_n='a_Ansprechzeit_plot.txt',
)
# Out:
# Fit-Ergebnisse für 1:
# Schwerpunkt: (148.35 ± 0.09, 0.912 ± 0.005)
# Steigung: 0.0009 ± 0.0010
# Y-Achsenabschnitt: 0.77 ± 0.18

# %%
# Normierung auf U_max

var_names=[t, U, U_max]=sp.symbols('t U U_max')
formula_list=[
    t,
    U / U_max,
    ]
evaluate_gaussian_error('a_Ansprechzeit.txt',formulas=formula_list, variables=var_names, result_length=10,result_names=['t', 'U/U_max'], output_file_suffix= 'plot')
# Out:
# sqrt((del_t)**2 + (0)**2 + (0)**2)
# sqrt((0)**2 + (del_U/U_max)**2 + (-U*del_U_max/U_max**2)**2)
# Zeile 1: [10.0, 0.5, 0.5683453237, 0.0041374982]
# Zeile 2: [20.0, 0.5, 0.7338129496, 0.00446171]
# Zeile 3: [30.0, 0.5, 0.7949640288, 0.0045952696]
# Zeile 4: [40.0, 0.5, 0.8309352518, 0.0046768862]
# Zeile 5: [50.0, 0.5, 0.8525179856, 0.00472688]
# Zeile 6: [60.0, 0.5, 0.8741007194, 0.0047776123]
# Zeile 7: [70.0, 0.5, 0.8848920863, 0.0048032481]
# Zeile 8: [80.0, 0.5, 0.8956834532, 0.0048290598]
# Zeile 9: [90.0, 0.5, 0.9100719424, 0.0048637443]
# Zeile 10: [100.0, 0.5, 0.9172661871, 0.0048811999]
# Zeile 11: [110.0, 0.5, 0.9244604317, 0.00489873]
# Zeile 12: [120.0, 0.5, 0.9316546763, 0.0049163338]
# Zeile 13: [130.0, 0.5, 0.9388489209, 0.0049340106]
# Zeile 14: [140.0, 0.5, 0.9424460432, 0.0049428761]
# Zeile 15: [150.0, 0.5, 0.9496402878, 0.0049606608]
# Zeile 16: [160.0, 0.5, 0.9532374101, 0.0049695798]
# Zeile 17: [170.0, 0.5, 0.9568345324, 0.0049785164]
# Zeile 18: [180.0, 0.5, 0.9604316547, 0.0049874707]
# Zeile 19: [190.0, 0.5, 0.964028777, 0.0049964423]
# Zeile 20: [200.0, 0.5, 0.9676258993, 0.0050054314]
# Zeile 21: [210.0, 0.5, 0.9712230216, 0.0050144377]
# Zeile 22: [220.0, 0.5, 0.9748201439, 0.0050234612]
# Zeile 23: [230.0, 0.5, 0.9784172662, 0.0050325018]
# Zeile 24: [240.0, 0.5, 0.9820143885, 0.0050415594]
# Zeile 25: [250.0, 0.5, 0.9856115108, 0.0050506339]
# Zeile 26: [260.0, 0.5, 0.9892086331, 0.0050597252]
# Zeile 27: [270.0, 0.5, 0.9928057554, 0.0050688333]
# Zeile 28: [280.0, 0.5, 0.9964028777, 0.0050779579]
# Zeile 29: [290.0, 0.5, 1.0, 0.0050870991]
# Zeile 30: [300.0, 0.5, 1.0, 0.0050870991]
# Auswertung abgeschlossen. Ergebnisse wurden in 'a_Ansprechzeit_plot.txt' gespeichert.

# %%
geraden_fit(
    file_n='a_Ansprechzeit_plot.txt',
    title=r'Abb. 1: Aufgabe a) Bestimmung der Ansprechzeit',
    y_label=r'$U / U_{max}$',
    x_label=r'Zeit $t$ [s]',
    save=True,
    length=11,
    height=6,
    x_axis=0,
    y_axis=0,
    x_major_ticks=50,   # Hauptticks alle 10 Einheiten
    x_minor_ticks=10,    # Nebenticks alle 1 Einheit
    y_major_ticks=0.2,
    y_minor_ticks=0.05,
    legendlocation='best',
    y_labels=['Messung'],  # Provide labels for each dataset
    # y_markers=['o'],       # Optional: specify markers
    y_colors=['blue'], # Optional: specify colors
    x_decimal_places=0,
    y_decimal_places=1,
    plot_errors =  True,
    size = 1.3
)
# Out:
# Fit-Ergebnisse für Messung:
# Schwerpunkt: (148.35 ± 0.09, 0.912 ± 0.005)
# Steigung: 0.0009 ± 0.0010
# Y-Achsenabschnitt: 0.77 ± 0.18

# %%
# wichtige Groessen

# Sensitivität der Thermosäule
S = 29 * 10**-3  # mV * m^2 / W
# Verstaerkungsfaktor
V = 100
# Offsetspannung U_0
U_0 = 0.61  # mV
err_U_0 = 0.04

# %% [markdown]
# # 372.c

# %%
# abgestrahlte Leistung berechnen
'''Unsicherheit von Offset U_0 noch nicht beruecksichtigt'''

var_names=[d, U, U_0]=sp.symbols('d U U_0')
formula_list=[
    d**(-3),
    (U - U_0) / (V * S),  # U_0 ohne err
    ]
evaluate_gaussian_error('c1.txt',formulas=formula_list, variables=var_names, result_length=20,result_names=['d^-3', 'I'], output_file_suffix= 'plot')
# Out:
# sqrt((-3*del_d/d**4)**2 + (0)**2 + (0)**2)
# sqrt((0)**2 + (0.344827586206897*del_U)**2 + (-0.344827586206897*del_U_0)**2)
# Zeile 1: [4.19589809003e-09, 2.030273269e-11, 13.444827586206896, 0.10436376517532106]
# Zeile 2: [7.11197086937e-09, 4.103060117e-11, 22.237931034482756, 0.10436376517532106]
# Zeile 3: [1.349746247705e-08, 9.641044626e-11, 41.51379310344827, 1.034574708557196]
# Zeile 4: [3.0517578125e-08, 2.8610229492e-10, 92.20344827586206, 1.3793793086207757]
# Zeile 5: [5.080526342529e-08, 5.6450292695e-10, 152.89310344827584, 0.17296463729633726]
# Zeile 6: [9.39143501127e-08, 1.28065022881e-09, 272.20344827586206, 0.6897930896579303]
# Auswertung abgeschlossen. Ergebnisse wurden in 'c1_plot.txt' gespeichert.

# %%
geraden_fit(
    exp_nr='',
    file_n='c1_plot.txt',
    title=r'Abb. 3: Aufgabe c) (I) Leistung $\phi / A$ gegen $1/r^3$',
    y_label=r'Leistung $\phi / A$ in [$\text{W} / \text{m}^2$]',
    x_label=r'$r^{-3}$ [$\text{mm}^{-3}$]',
    save=True,
    length=11,
    height=6,
    x_axis=0,
    y_axis=0,
    # x_major_ticks=50,   # Hauptticks alle 10 Einheiten
    # x_minor_ticks=10,    # Nebenticks alle 1 Einheit
    # y_major_ticks=0.2,
    # y_minor_ticks=0.05,
    legendlocation='best',
    y_labels=['Messung'],  # Provide labels for each dataset
    # y_markers=['o'],       # Optional: specify markers
    y_colors=['blue'], # Optional: specify colors
    x_decimal_places=0,
    y_decimal_places=1,
    plot_errors =  True,
    linear_fit=True,
    plot_y_inter=True,
    size = 1.3
)
# Out:
# Fit-Ergebnisse für Messung:
# Schwerpunkt: (0.00000001343 ± 0.00000000024, 41.00 ± 0.16)
# Steigung: 2969000000 ± 4000000
# Y-Achsenabschnitt: 1.14 ± 0.08

# %%
# Temp.koeffizienten
a = 4.82 * 10**-3
b = 6.76 * 10**-7

# Temp., abgestrahlte Leistung berechnen

var_names=[I, U_L, U, T_0, R_0, U_0]=sp.symbols('I U_L U T_0 R_0 U_0')
formula_list=[
    T_0 - a/(2*b) + sp.sqrt((U_L/(I * R_0) - 1 + a**2/(4*b)) / b),
    (U - U_0) / (V * S),  # U_0 ohne err
    ]
evaluate_gaussian_error('c2.txt',formulas=formula_list, variables=var_names, result_length=10,result_names=['T', 'I'], output_file_suffix= 'T_I')
# Out:
# sqrt((-220.710222859342*U_L*del_I/(I**2*R_0*sqrt(1 + 0.131719958691374*U_L/(I*R_0))))**2 + (220.710222859342*del_U_L/(I*R_0*sqrt(1 + 0.131719958691374*U_L/(I*R_0))))**2 + (0)**2 + (del_T_0)**2 + (-220.710222859342*U_L*del_R_0/(I*R_0**2*sqrt(1 + 0.131719958691374*U_L/(I*R_0))))**2 + (0)**2)
# sqrt((0)**2 + (0)**2 + (0.344827586206897*del_U)**2 + (0)**2 + (0)**2 + (-0.344827586206897*del_U_0)**2)
# Zeile 1: [365.6482437716, 83.1602396355, 14.2724137931, 3.4483034482]
# Zeile 2: [432.8788741547, 65.5115356585, 15.2379310345, 0.6897930897]
# Zeile 3: [603.2289891306, 84.1015021872, 27.375862069, 3.4483034482]
# Zeile 4: [690.3989909231, 95.0912872934, 54.9620689655, 6.8965655172]
# Zeile 5: [776.6592492652, 106.6334745303, 85.9965517241, 13.7931103448]
# Zeile 6: [853.1487351981, 116.9644564566, 130.824137931, 13.7931103448]
# Zeile 7: [938.3426367052, 128.468313504, 179.1, 5.1724321839]
# Zeile 8: [1024.3942308964, 139.9838465565, 256.6862068966, 3.4483034482]
# Zeile 9: [1029.0671245496, 140.5972624853, 272.2034482759, 0.6897930897]
# Auswertung abgeschlossen. Ergebnisse wurden in 'c2_T_I.txt' gespeichert.

# %%
# phi/A gegen T zur Kontrolle

geraden_fit(
    exp_nr='',
    file_n='c2_T_I.txt',
    # title=r'Abb. 3: Aufgabe c) Leistung $\phi / A$ gegen $1/r^3$',
    # y_label=r'Leistung $\phi / A$ in [$\text{W} / \text{m}^2$]',
    # x_label=r'$r^{-3}$ [$\text{mm}^{-3}$]',
    # save=True,
    length=11,
    height=6,
    # x_axis=0,
    # y_axis=0,
    # x_major_ticks=50,   # Hauptticks alle 10 Einheiten
    # x_minor_ticks=10,    # Nebenticks alle 1 Einheit
    # y_major_ticks=0.2,
    # y_minor_ticks=0.05,
    legendlocation='best',
    # y_labels=['Messung'],  # Provide labels for each dataset
    # y_markers=['o'],       # Optional: specify markers
    y_colors=['blue'], # Optional: specify colors
    x_decimal_places=0,
    y_decimal_places=1,
    plot_errors =  True,
    size = 1.3
)
# Out:
# Fit-Ergebnisse für 1:
# Schwerpunkt: (730 ± 40, 141.0 ± 1.4)
# Steigung: 0.43 ± 0.11
# Y-Achsenabschnitt: -170 ± 90

# %%
# log anwenden

var_names=[T, I]=sp.symbols('T I')
formula_list=[
    sp.ln(T),
    sp.ln(I)
    ]
evaluate_gaussian_error('c2_T_I.txt',formulas=formula_list, variables=var_names, result_length=10,result_names=['log_T', 'log_I'], output_file_suffix= 'log')
# Out:
# sqrt((del_T/T)**2 + (0)**2)
# sqrt((0)**2 + (del_I/I)**2)
# Zeile 1: [5.9016717887, 0.2274323508, 2.6583285688, 0.2416061851]
# Zeile 2: [6.0704579525, 0.1513391842, 2.7237877822, 0.0452681593]
# Zeile 3: [6.4022968744, 0.139418867, 3.3096616787, 0.1259614561]
# Zeile 4: [6.5372696782, 0.1377338156, 4.0066432921, 0.1254786373]
# Zeile 5: [6.6550017075, 0.1372976304, 4.4543071992, 0.1603914351]
# Zeile 6: [6.7489338995, 0.1370973801, 4.8738539628, 0.1054324574]
# Zeile 7: [6.8441151666, 0.1369098115, 5.1879443091, 0.028880135]
# Zeile 8: [6.9318567226, 0.136650366, 5.547854354, 0.0134339258]
# Zeile 9: [6.9364079665, 0.1366259393, 5.6065497583, 0.0025341086]
# Auswertung abgeschlossen. Ergebnisse wurden in 'c2_T_I_log.txt' gespeichert.

# %%
geraden_fit(
    exp_nr='',
    file_n='c2_T_I_log.txt',
    title=r'Abb. 4: Aufgabe c) (II) $\log(\phi / A)$ gegen $\log(T)$',
    y_label=r'$\log(\phi / A)$ in [$\text{W} / \text{m}^2$]',
    x_label=r'$\log(T)$ [$\text{mm}^{-3}$]',
    save=True,
    length=11,
    height=6,
    x_axis=0,
    y_axis=0,
    # x_major_ticks=50,   # Hauptticks alle 10 Einheiten
    # x_minor_ticks=10,    # Nebenticks alle 1 Einheit
    # y_major_ticks=0.2,
    # y_minor_ticks=0.05,
    legendlocation='best',
    y_labels=['Messung'],  # Provide labels for each dataset
    # y_markers=['o'],       # Optional: specify markers
    y_colors=['blue'], # Optional: specify colors
    x_decimal_places=0,
    y_decimal_places=1,
    plot_errors =  True,
    linear_fit=True,
    plot_y_inter=True,
    size = 1.3
)
# Out:
# Fit-Ergebnisse für Messung:
# Schwerpunkt: (6.93 ± 0.05, 5.590 ± 0.007)
# Steigung: 3.4 ± 1.1
# Y-Achsenabschnitt: -18 ± 8
