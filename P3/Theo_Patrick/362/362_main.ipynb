# %%
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⢀⡔⣻⠁⠀⢀⣀⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⢀⣾⠳⢶⣦⠤⣀⠀⠀⠀⠀⠀⠀⠀⣾⢀⡇⡴⠋⣀⠴⣊⣩⣤⠶⠞⢹⣄⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⠀⢠⠈⠙⠢⣙⠲⢤⠤⠤⠀⠒⠳⡄⣿⢀⠾⠓⢋⠅⠛⠉⠉⠝⠀⠼⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⢰⡀⠁⠀⠀⠈⠑⠦⡀⠀⠀⠀⠀⠈⠺⢿⣂⠀⠉⠐⠲⡤⣄⢉⠝⢸⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⢀⡹⠆⠀⠀⠀⠀⡠⠃⠀⠀⠀⠀⠀⠀⠀⠉⠙⠲⣄⠀⠀⠙⣷⡄⢸⠀⠀⠀
#⠀⠀⠀⠀⢸⡀⠙⠂⢠⠀⠀⡠⠊⠀⠀⠀⠀⢠⠀⠀⠀⠀⠘⠄⠀⠀⠑⢦⣔⠀⢡⡸⠀⠀⠀
#⠀⠀⠀⠀⢀⣧⠀⢀⡧⣴⠯⡀⠀⠀⠀⠀⠀⡎⠀⠀⠀⠀⠀⢸⡠⠔⠈⠁⠙⡗⡤⣷⡀⠀⠀
#⠀⠀⠀⠀⡜⠈⠚⠁⣬⠓⠒⢼⠅⠀⠀⠀⣠⡇⠀⠀⠀⠀⠀⠀⣧⠀⠀⠀⡀⢹⠀⠸⡄⠀⠀
#⠀⠀⠀⡸⠀⠀⠀⠘⢸⢀⠐⢃⠀⠀⠀⡰⠋⡇⠀⠀⠀⢠⠀⠀⡿⣆⠀⠀⣧⡈⡇⠆⢻⠀⠀
#⠀⠀⢰⠃⠀⠀⢀⡇⠼⠉⠀⢸⡤⠤⣶⡖⠒⠺⢄⡀⢀⠎⡆⣸⣥⠬⠧⢴⣿⠉⠸⡀⣇⠀
#⠀⠀⠇⠀⠀⠀⢸⠀⠀⠀⣰⠋⠀⢸⣿⣿⠀⠀⠀⠙⢧⡴⢹⣿⣿⠀⠀⠀⠈⣆⠀⠀⢧⢹⡄
#⠀⣸⠀⢠⠀⠀⢸⡀⠀⠀⢻⡀⠀⢸⣿⣿⠀⠀⠀⠀⡼⣇⢸⣿⣿⠀⠀⠀⢀⠏⠀⠀⢸⠀⠇
#⠀⠓⠈⢃⠀⠀⠀⡇⠀⠀⠀⣗⠦⣀⣿⡇⠀⣀⠤⠊⠀⠈⠺⢿⣃⣀⠤⠔⢸⠀⠀⠀⣼⠑⢼
#⠀⠀⠀⢸⡀⣀⣾⣷⡀⠀⢸⣯⣦⡀⠀⠀⠀⢇⣀⣀⠐⠦⣀⠘⠀⠀⢀⣰⣿⣄⠀⠀⡟⠀⠀
#⠀⠀⠀⠀⠛⠁⣿⣿⣧⠀⣿⣿⣿⣿⣦⣀⠀⠀⠀⠀⠀⠀⠀⣀⣠⣴⣿⣿⡿⠈⠢⣼⡇⠀⠀
#⠀⠀⠀⠀⠀⠀⠈⠁⠈⠻⠈⢻⡿⠉⣿⠿⠛⡇⠒⠒⢲⠺⢿⣿⣿⠉⠻⡿⠁⠀⠀⠈⠁⠀⠀
#⢀⠤⠒⠦⡀⠀⠀⠀⠀⠀⠀⠀⢀⠞⠉⠆⠀⠀⠉⠉⠉⠀⠀⡝⣍⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⡎⠀⠀⠀⡇⠀⠀⠀⠀⠀⠀⡰⠋⠀⠀⢸⠀⠀⠀⠀⠀⠀⠀⢡⠈⢦⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⡇⠀⠀⠸⠁⠀⠀⠀⠀⢀⠜⠁⠀⠀⠀⡸⠀⠀⠀⠀⠀⠀⠀⠘⡄⠈⢳⡀⠀⠀⠀⠀⠀⠀⠀
#⡇⠀⠀⢠⠀⠀⠀⠀⠠⣯⣀⠀⠀⠀⡰⡇⠀⠀⠀⠀⠀⠀⠀⠀⢣⠀⢀⡦⠤⢄⡀⠀⠀⠀⠀
#⢱⡀⠀⠈⠳⢤⣠⠖⠋⠛⠛⢷⣄⢠⣷⠁⠀⠀⠀⠀⠀⠀⠀⠀⠘⡾⢳⠃⠀⠘⢇⠀⠀⠀
#⠀⠙⢦⡀⠀⢠⠁⠀⠀⠀⠀⠀⠙⣿⣏⣀⠀⠀⠀⠀⠀⠀⠀⣀⣴⣧⡃⠀⠀⠀ ⠀⣸⠀⠀⠀
#⠀⠀⠀⠈⠉⢺⣄⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣗⣤⣀⣠⡾⠃⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠣⢅⡤⣀⣀⣠⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⠉⠉⠉⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⠉⠁⠀⠉⣿⣿⣿⣿⣿⡿⠻⣿⣿⣿⣿⠛⠉⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⣿⣿⣿⠀⠀⠀⠀⣿⣿⣿⡿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⣿⣿⣿⣟⠀⠀⢠⣿⣿⣿⣿⣧⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⣿⣿⣿⣿⣿⠀⠀⢸⣿⣿⣿⣿⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⡏⠀⠀⢸⣿⣿⣿⣿⣿⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⣿⣿⣿⠀⠀⠀⢺⣿⣿⣿⣿⣿⣿⣷⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⠀⠀⠀⠀⠈⠉⠻⣿⣿⣿⠟⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⢿⣿⣿⣿⠏⠀⠀⠀⠀⠀⠀⠀⠀
# 


import sys
import os
import sympy as sp
import numpy as np
import pandas as pd

# Add the correct path to the P2 folder
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

from gauss_fehlerfortpflanzung import evaluate_gaussian_error
from geraden_fit import geraden_fit
from scientific_error_rounder import runden_und_speichern
from mean_calc_w_err import err_weighted_mean
from data_handler import add_column_to_file
from tabelle import tabellen_ersteller

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import seaborn as sns

# %%
var_names=[B, R, z, x_0, G]=sp.symbols('B R z x_0 G')
formula_list=[
    R - x_0,
    z - R,
    B / G
    ]
evaluate_gaussian_error('a_roh.txt',formulas=formula_list, variables=var_names, result_length=10,result_names=['x', 'z', 'y'], output_file_suffix= 'temp')
# Out:
# sqrt((0)**2 + (del_R)**2 + (0)**2 + (-del_x_0)**2 + (0)**2)
# sqrt((0)**2 + (-del_R)**2 + (del_z)**2 + (0)**2 + (0)**2)
# sqrt((del_B/G)**2 + (0)**2 + (0)**2 + (0)**2 + (-B*del_G/G**2)**2)
# Zeile 1: [14.5, 0.0707106781, 13.55, 5.0002499938, 2.6956521739, 0.438714041]
# Zeile 2: [14.8, 0.0707106781, 15.2, 5.0002499938, 2.7826086957, 0.438970543]
# Zeile 3: [14.8, 0.0707106781, 16.2, 5.0002499938, 2.8695652174, 0.4392350309]
# Zeile 4: [15.1, 0.0707106781, 15.9, 5.0002499938, 2.7826086957, 0.438970543]
# Zeile 5: [15.7, 0.0707106781, 13.4, 5.0002499938, 2.2608695652, 0.4375517961]
# Zeile 6: [16.0, 0.0707106781, 14.25, 5.0002499938, 2.347826087, 0.4377681664]
# Zeile 7: [16.3, 0.0707106781, 15.7, 5.0002499938, 2.5217391304, 0.4382250504]
# Zeile 8: [16.6, 0.0707106781, 14.8, 5.0002499938, 2.3913043478, 0.4378793718]
# Zeile 9: [16.9, 0.0707106781, 12.2, 5.0002499938, 1.9565217391, 0.4368580774]
# Zeile 10: [17.9, 0.0707106781, 11.3, 5.0002499938, 1.9565217391, 0.4368580774]
# Auswertung abgeschlossen. Ergebnisse wurden in 'a_roh_temp.csv' gespeichert.

# %%
var_names=[x, z, y]=sp.symbols('x z y')
formula_list=[
    1+1/y,
    x,
    ]
evaluate_gaussian_error('a_roh_temp.csv',formulas=formula_list, variables=var_names, result_length=10,result_names=['1+1/y', 'x'], output_file_suffix= 'plotx')
var_names=[x, z, y]=sp.symbols('x z y')
formula_list=[
    1+y,
    z,
    ]
evaluate_gaussian_error('a_roh_temp.csv',formulas=formula_list, variables=var_names, result_length=10,result_names=['1+y', 'z'], output_file_suffix= 'ploty')
# Out:
# sqrt((0)**2 + (0)**2 + (-del_y/y**2)**2)
# sqrt((del_x)**2 + (0)**2 + (0)**2)
# Zeile 1: [1.3709677419, 0.0603745389, 14.5, 0.0707106781]
# Zeile 2: [1.359375, 0.0566932171, 14.8, 0.0707106781]
# Zeile 3: [1.3484848485, 0.0533414443, 14.8, 0.0707106781]
# Zeile 4: [1.359375, 0.0566932171, 15.1, 0.0707106781]
# Zeile 5: [1.4423076923, 0.0856009246, 15.7, 0.0707106781]
# Zeile 6: [1.4259259259, 0.0794167901, 16.0, 0.0707106781]
# Zeile 7: [1.3965517241, 0.0689123221, 16.3, 0.0707106781]
# Zeile 8: [1.4181818182, 0.0765746075, 16.6, 0.0707106781]
# Zeile 9: [1.5111111111, 0.1141224311, 16.9, 0.0707106781]
# Zeile 10: [1.5111111111, 0.1141224311, 17.9, 0.0707106781]
# Auswertung abgeschlossen. Ergebnisse wurden in 'a_roh_temp_plotx.csv' gespeichert.
# sqrt((0)**2 + (0)**2 + (del_y)**2)
# sqrt((0)**2 + (del_z)**2 + (0)**2)
# Zeile 1: [3.6956521739, 0.438714041, 13.55, 5.0002499938]
# Zeile 2: [3.7826086957, 0.438970543, 15.2, 5.0002499938]
# Zeile 3: [3.8695652174, 0.4392350309, 16.2, 5.0002499938]
# Zeile 4: [3.7826086957, 0.438970543, 15.9, 5.0002499938]
# Zeile 5: [3.2608695652, 0.4375517961, 13.4, 5.0002499938]
# Zeile 6: [3.347826087, 0.4377681664, 14.25, 5.0002499938]
# Zeile 7: [3.5217391304, 0.4382250504, 15.7, 5.0002499938]
# Zeile 8: [3.3913043478, 0.4378793718, 14.8, 5.0002499938]
# Zeile 9: [2.9565217391, 0.4368580774, 12.2, 5.0002499938]
# Zeile 10: [2.9565217391, 0.4368580774, 11.3, 5.0002499938]
# Auswertung abgeschlossen. Ergebnisse wurden in 'a_roh_temp_ploty.csv' gespeichert.

# %%
geraden_fit('a_roh_temp_plotx.csv', x_min = 1.25, x_max = 1.6, y_min = 14, y_max = 18.5, y_label = 'x', x_label = r'$1+1/\gamma$', x_decimal_places = 2)
geraden_fit('a_roh_temp_ploty.csv', x_min = 2.2, x_max = 4.4, y_min = 7, y_max = 20, y_label = f"x'", x_label = r'$1+\gamma$')
# Out:
# 16.10085219170874 16.855440531355516
# Fit-Ergebnisse für 1:
# Schwerpunkt: (1.39 ± 0.07, 15.45 ± 0.07)
# Steigung: 17 ± 8
# Y-Achsenabschnitt: -8 ± 11
# 4.214853358306914 4.217816896700128
# Fit-Ergebnisse für 1:
# Schwerpunkt: (3.5 ± 0.4, 14 ± 5)
# Steigung: 4 ± 5
# Y-Achsenabschnitt: -0 ± 19

# %%
runden_und_speichern('a_roh_temp_plotx.csv')
runden_und_speichern('a_roh_temp_ploty.csv')
# Out:
# Die gerundeten Daten wurden in der CSV-Datei "a_roh_temp_plotx_rounded.csv" gespeichert.
# Die gerundeten Daten wurden in der CSV-Datei "a_roh_temp_ploty_rounded.csv" gespeichert.

# %%
# Untergrundmessung Luxmeter

U = np.mean([3.6, 3.6, 3.1, 3.3, 3.9, 3.9, 3.5, 4.0, 3.8, 4.1])
print(U)
err_U = np.std([3.6, 3.6, 3.1, 3.3, 3.9, 3.9, 3.5, 4.0, 3.8, 4.1])
print(err_U)
# Out:
# 3.6800000000000006
# 0.30265491900843106

# %%
# Create a 5x5 grid with NaN values for missing cells
grid = np.ones((5, 5))

# Set corners to NaN (missing)
grid[0, 0] = np.nan  # Top-left
grid[0, 4] = np.nan  # Top-right
grid[4, 0] = np.nan  # Bottom-left
grid[4, 4] = np.nan  # Bottom-right

# Set middle to NaN (missing)
grid[2, 2] = np.nan  # Center

# load data from csv
data = np.loadtxt("e_f_g.csv", delimiter=",")

# Fill the grid with values
n = 0
for i in range(5):
    for j in range(5):
        if not np.isnan(grid[i, j]):
            grid[i, j] = data[n, 1] - U  # values corrected with Untergrundmessung
            n += 1

# Create a custom colormap that doesn't color NaN values
cmap = plt.cm.viridis.copy()
cmap.set_bad('white', 1.0)

# Create the heatmap
plt.figure(figsize=(6, 4))
ax = sns.heatmap(grid, cmap=cmap, annot=True, fmt=".1f", linewidths=.5, 
                square=True, mask=np.isnan(grid))

# Add title and labels
plt.title('362.e', fontsize=16)
plt.xlabel('Spalte', fontsize=12)
plt.ylabel('Reihe', fontsize=12)

# If you need to save the plot
plt.savefig('e.png', dpi=300, bbox_inches='tight')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create a 5x5 grid with NaN values for missing cells
grid = np.ones((5, 5))

# Set corners to NaN (missing)
grid[0, 0] = np.nan  # Top-left
grid[0, 4] = np.nan  # Top-right
grid[4, 0] = np.nan  # Bottom-left
grid[4, 4] = np.nan  # Bottom-right

# Set middle to NaN (missing)
grid[2, 2] = np.nan  # Center

# load data from csv
data = np.loadtxt("e_f_g.csv", delimiter=",")

# Fill the grid with values
n = 0
for i in range(5):
    for j in range(5):
        if not np.isnan(grid[i, j]):
            grid[i, j] = data[n, 2] - U  # values corrected with Untergrundmessung
            n += 1

# Create a custom colormap that doesn't color NaN values
cmap = plt.cm.viridis.copy()
cmap.set_bad('white', 1.0)

# Create the heatmap
plt.figure(figsize=(6, 4))
ax = sns.heatmap(grid, cmap=cmap, annot=True, fmt=".1f", linewidths=.5, 
                square=True, mask=np.isnan(grid))

# Add title and labels
plt.title('362.f', fontsize=16)
plt.xlabel('Spalte', fontsize=12)
plt.ylabel('Reihe', fontsize=12)

# If you need to save the plot
plt.savefig('f.png', dpi=300, bbox_inches='tight')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create a 5x5 grid with NaN values for missing cells
grid = np.ones((5, 5))

# Set corners to NaN (missing)
grid[0, 0] = np.nan  # Top-left
grid[0, 4] = np.nan  # Top-right
grid[4, 0] = np.nan  # Bottom-left
grid[4, 4] = np.nan  # Bottom-right

# Set middle to NaN (missing)
grid[2, 2] = np.nan  # Center

# load data from csv
data = np.loadtxt("e_f_g.csv", delimiter=",")

# Fill the grid with values
n = 0
for i in range(5):
    for j in range(5):
        if not np.isnan(grid[i, j]):
            grid[i, j] = data[n, 3] - U  # values corrected with Untergrundmessung
            n += 1

# Create a custom colormap that doesn't color NaN values
cmap = plt.cm.viridis.copy()
cmap.set_bad('white', 1.0)

# Create the heatmap
plt.figure(figsize=(6, 4))
ax = sns.heatmap(grid, cmap=cmap, annot=True, fmt=".1f", linewidths=.5, 
                square=True, mask=np.isnan(grid))

# Add title and labels
plt.title('362.g', fontsize=16)
plt.xlabel('Spalte', fontsize=12)
plt.ylabel('Reihe', fontsize=12)

# If you need to save the plot
plt.savefig('g.png', dpi=300, bbox_inches='tight')

# Show the plot
plt.tight_layout()
plt.show()
