# %%
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⢀⡔⣻⠁⠀⢀⣀⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⢀⣾⠳⢶⣦⠤⣀⠀⠀⠀⠀⠀⠀⠀⣾⢀⡇⡴⠋⣀⠴⣊⣩⣤⠶⠞⢹⣄⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⠀⢠⠈⠙⠢⣙⠲⢤⠤⠤⠀⠒⠳⡄⣿⢀⠾⠓⢋⠅⠛⠉⠉⠝⠀⠼⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⢰⡀⠁⠀⠀⠈⠑⠦⡀⠀⠀⠀⠀⠈⠺⢿⣂⠀⠉⠐⠲⡤⣄⢉⠝⢸⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⢀⡹⠆⠀⠀⠀⠀⡠⠃⠀⠀⠀⠀⠀⠀⠀⠉⠙⠲⣄⠀⠀⠙⣷⡄⢸⠀⠀⠀
#⠀⠀⠀⠀⢸⡀⠙⠂⢠⠀⠀⡠⠊⠀⠀⠀⠀⢠⠀⠀⠀⠀⠘⠄⠀⠀⠑⢦⣔⠀⢡⡸⠀⠀⠀
#⠀⠀⠀⠀⢀⣧⠀⢀⡧⣴⠯⡀⠀⠀⠀⠀⠀⡎⠀⠀⠀⠀⠀⢸⡠⠔⠈⠁⠙⡗⡤⣷⡀⠀⠀
#⠀⠀⠀⠀⡜⠈⠚⠁⣬⠓⠒⢼⠅⠀⠀⠀⣠⡇⠀⠀⠀⠀⠀⠀⣧⠀⠀⠀⡀⢹⠀⠸⡄⠀⠀
#⠀⠀⠀⡸⠀⠀⠀⠘⢸⢀⠐⢃⠀⠀⠀⡰⠋⡇⠀⠀⠀⢠⠀⠀⡿⣆⠀⠀⣧⡈⡇⠆⢻⠀⠀
#⠀⠀⢰⠃⠀⠀⢀⡇⠼⠉⠀⢸⡤⠤⣶⡖⠒⠺⢄⡀⢀⠎⡆⣸⣥⠬⠧⢴⣿⠉⠸⡀⣇⠀
#⠀⠀⠇⠀⠀⠀⢸⠀⠀⠀⣰⠋⠀⢸⣿⣿⠀⠀⠀⠙⢧⡴⢹⣿⣿⠀⠀⠀⠈⣆⠀⠀⢧⢹⡄
#⠀⣸⠀⢠⠀⠀⢸⡀⠀⠀⢻⡀⠀⢸⣿⣿⠀⠀⠀⠀⡼⣇⢸⣿⣿⠀⠀⠀⢀⠏⠀⠀⢸⠀⠇
#⠀⠓⠈⢃⠀⠀⠀⡇⠀⠀⠀⣗⠦⣀⣿⡇⠀⣀⠤⠊⠀⠈⠺⢿⣃⣀⠤⠔⢸⠀⠀⠀⣼⠑⢼
#⠀⠀⠀⢸⡀⣀⣾⣷⡀⠀⢸⣯⣦⡀⠀⠀⠀⢇⣀⣀⠐⠦⣀⠘⠀⠀⢀⣰⣿⣄⠀⠀⡟⠀⠀
#⠀⠀⠀⠀⠛⠁⣿⣿⣧⠀⣿⣿⣿⣿⣦⣀⠀⠀⠀⠀⠀⠀⠀⣀⣠⣴⣿⣿⡿⠈⠢⣼⡇⠀⠀
#⠀⠀⠀⠀⠀⠀⠈⠁⠈⠻⠈⢻⡿⠉⣿⠿⠛⡇⠒⠒⢲⠺⢿⣿⣿⠉⠻⡿⠁⠀⠀⠈⠁⠀⠀
#⢀⠤⠒⠦⡀⠀⠀⠀⠀⠀⠀⠀⢀⠞⠉⠆⠀⠀⠉⠉⠉⠀⠀⡝⣍⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⡎⠀⠀⠀⡇⠀⠀⠀⠀⠀⠀⡰⠋⠀⠀⢸⠀⠀⠀⠀⠀⠀⠀⢡⠈⢦⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⡇⠀⠀⠸⠁⠀⠀⠀⠀⢀⠜⠁⠀⠀⠀⡸⠀⠀⠀⠀⠀⠀⠀⠘⡄⠈⢳⡀⠀⠀⠀⠀⠀⠀⠀
#⡇⠀⠀⢠⠀⠀⠀⠀⠠⣯⣀⠀⠀⠀⡰⡇⠀⠀⠀⠀⠀⠀⠀⠀⢣⠀⢀⡦⠤⢄⡀⠀⠀⠀⠀
#⢱⡀⠀⠈⠳⢤⣠⠖⠋⠛⠛⢷⣄⢠⣷⠁⠀⠀⠀⠀⠀⠀⠀⠀⠘⡾⢳⠃⠀⠘⢇⠀⠀⠀
#⠀⠙⢦⡀⠀⢠⠁⠀⠀⠀⠀⠀⠙⣿⣏⣀⠀⠀⠀⠀⠀⠀⠀⣀⣴⣧⡃⠀⠀⠀ ⠀⣸⠀⠀⠀
#⠀⠀⠀⠈⠉⢺⣄⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣗⣤⣀⣠⡾⠃⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠣⢅⡤⣀⣀⣠⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⠉⠉⠉⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⠉⠁⠀⠉⣿⣿⣿⣿⣿⡿⠻⣿⣿⣿⣿⠛⠉⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⣿⣿⣿⠀⠀⠀⠀⣿⣿⣿⡿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⣿⣿⣿⣟⠀⠀⢠⣿⣿⣿⣿⣧⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⣿⣿⣿⣿⣿⠀⠀⢸⣿⣿⣿⣿⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⡏⠀⠀⢸⣿⣿⣿⣿⣿⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⣿⣿⣿⠀⠀⠀⢺⣿⣿⣿⣿⣿⣿⣷⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⠀⠀⠀⠀⠈⠉⠻⣿⣿⣿⠟⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⢿⣿⣿⣿⠏⠀⠀⠀⠀⠀⠀⠀⠀
# 


import sys
import os
import sympy as sp
import numpy as np
import pandas as pd

# Add the correct path to the P2 folder
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

from gauss_fehlerfortpflanzung import evaluate_gaussian_error
from geraden_fit import geraden_fit
from scientific_error_rounder import runden_und_speichern
from mean_calc_w_err import err_weighted_mean
from data_handler import add_column_to_file
from tabelle import tabellen_ersteller

# %%
var_names=[B, R, z, x_0, G]=sp.symbols('B R z x_0 G')
formula_list=[
    R - x_0,
    z - R,
    B / G
    ]
evaluate_gaussian_error('a_roh.txt',formulas=formula_list, variables=var_names, result_length=10,result_names=['x', 'z', 'y'], output_file_suffix= 'temp')
# Out:
# sqrt((0)**2 + (del_R)**2 + (0)**2 + (-del_x_0)**2 + (0)**2)
# sqrt((0)**2 + (-del_R)**2 + (del_z)**2 + (0)**2 + (0)**2)
# sqrt((del_B/G)**2 + (0)**2 + (0)**2 + (0)**2 + (-B*del_G/G**2)**2)
# Zeile 1: [14.5, 0.0707106781, 13.55, 0.0707106781, 2.6956521739, 0.0729688433]
# Zeile 2: [14.8, 0.0707106781, 15.2, 0.0707106781, 2.7826086957, 0.0744955028]
# Zeile 3: [14.8, 0.0707106781, 16.2, 0.0707106781, 2.8695652174, 0.076038508]
# Zeile 4: [15.1, 0.0707106781, 15.9, 0.0707106781, 2.7826086957, 0.0744955028]
# Zeile 5: [15.7, 0.0707106781, 13.4, 0.0707106781, 2.2608695652, 0.0656202456]
# Zeile 6: [16.0, 0.0707106781, 14.25, 0.0707106781, 2.347826087, 0.067047818]
# Zeile 7: [16.3, 0.0707106781, 15.7, 0.0707106781, 2.5217391304, 0.06996883]
# Zeile 8: [16.6, 0.0707106781, 14.8, 0.0707106781, 2.3913043478, 0.0677701012]
# Zeile 9: [16.9, 0.0707106781, 12.2, 0.0707106781, 1.9565217391, 0.0608228754]
# Zeile 10: [17.9, 0.0707106781, 11.3, 0.0707106781, 1.9565217391, 0.0608228754]
# Auswertung abgeschlossen. Ergebnisse wurden in 'a_roh_temp.csv' gespeichert.

# %%
var_names=[x, z, y]=sp.symbols('x z y')
formula_list=[
    1+1/y,
    x,
    ]
evaluate_gaussian_error('a_roh_temp.csv',formulas=formula_list, variables=var_names, result_length=10,result_names=['x', '1+1/y'], output_file_suffix= 'plotx')
var_names=[x, z, y]=sp.symbols('x z y')
formula_list=[
    1+y,
    z,
    ]
evaluate_gaussian_error('a_roh_temp.csv',formulas=formula_list, variables=var_names, result_length=10,result_names=['z', '1+y'], output_file_suffix= 'ploty')
# Out:
# sqrt((0)**2 + (0)**2 + (-del_y/y**2)**2)
# sqrt((del_x)**2 + (0)**2 + (0)**2)
# Zeile 1: [1.3709677419, 0.0100417581, 14.5, 0.0707106781]
# Zeile 2: [1.359375, 0.0096211233, 14.8, 0.0707106781]
# Zeile 3: [1.3484848485, 0.0092342449, 14.8, 0.0707106781]
# Zeile 4: [1.359375, 0.0096211233, 15.1, 0.0707106781]
# Zeile 5: [1.4423076923, 0.0128376886, 15.7, 0.0707106781]
# Zeile 6: [1.4259259259, 0.0121633387, 16.0, 0.0707106781]
# Zeile 7: [1.3965517241, 0.0110028273, 16.3, 0.0707106781]
# Zeile 8: [1.4181818182, 0.0118513665, 16.6, 0.0707106781]
# Zeile 9: [1.5111111111, 0.0158890376, 16.9, 0.0707106781]
# Zeile 10: [1.5111111111, 0.0158890376, 17.9, 0.0707106781]
# Auswertung abgeschlossen. Ergebnisse wurden in 'a_roh_temp_plotx.csv' gespeichert.
# sqrt((0)**2 + (0)**2 + (del_y)**2)
# sqrt((0)**2 + (del_z)**2 + (0)**2)
# Zeile 1: [3.6956521739, 0.0729688433, 13.55, 0.0707106781]
# Zeile 2: [3.7826086957, 0.0744955028, 15.2, 0.0707106781]
# Zeile 3: [3.8695652174, 0.076038508, 16.2, 0.0707106781]
# Zeile 4: [3.7826086957, 0.0744955028, 15.9, 0.0707106781]
# Zeile 5: [3.2608695652, 0.0656202456, 13.4, 0.0707106781]
# Zeile 6: [3.347826087, 0.067047818, 14.25, 0.0707106781]
# Zeile 7: [3.5217391304, 0.06996883, 15.7, 0.0707106781]
# Zeile 8: [3.3913043478, 0.0677701012, 14.8, 0.0707106781]
# Zeile 9: [2.9565217391, 0.0608228754, 12.2, 0.0707106781]
# Zeile 10: [2.9565217391, 0.0608228754, 11.3, 0.0707106781]
# Auswertung abgeschlossen. Ergebnisse wurden in 'a_roh_temp_ploty.csv' gespeichert.

# %%
geraden_fit('a_roh_temp_plotx.csv')
geraden_fit('a_roh_temp_ploty.csv')
# Out:
# 16.10085219170874 16.611782241540897
# Fit-Ergebnisse für 1:
# Schwerpunkt: (1.397 ± 0.011, 15.58 ± 0.07)
# Steigung: 16.5 ± 1.3
# Y-Achsenabschnitt: -7.5 ± 1.8
# 4.214853358306985 4.346663182853366
# Fit-Ergebnisse für 1:
# Schwerpunkt: (3.41 ± 0.07, 14.05 ± 0.07)
# Steigung: 4.3 ± 0.3
# Y-Achsenabschnitt: -0.7 ± 1.0
