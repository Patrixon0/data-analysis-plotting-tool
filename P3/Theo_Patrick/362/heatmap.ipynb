# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import seaborn as sns

# Create a 5x5 grid with NaN values for missing cells
grid = np.ones((5, 5))

# Set corners to NaN (missing)
grid[0, 0] = np.nan  # Top-left
grid[0, 4] = np.nan  # Top-right
grid[4, 0] = np.nan  # Bottom-left
grid[4, 4] = np.nan  # Bottom-right

# Set middle to NaN (missing)
grid[2, 2] = np.nan  # Center

# Fill the grid with example values (replace with your actual values)
# I'll use a sample where values increase from top-left to bottom-right
for i in range(5):
    for j in range(5):
        if not np.isnan(grid[i, j]):
            grid[i, j] = i + j  # Sample values

# Create a custom colormap that doesn't color NaN values
cmap = plt.cm.viridis.copy()
cmap.set_bad('white', 1.0)

# Create the heatmap
plt.figure(figsize=(6, 4))
ax = sns.heatmap(grid, cmap=cmap, annot=True, fmt=".1f", linewidths=.5, 
                square=True, mask=np.isnan(grid))

# Add title and labels
plt.title('5x5 Grid Heatmap (without corners and center)', fontsize=16)
plt.xlabel('Column', fontsize=12)
plt.ylabel('Row', fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()

# If you need to save the plot
# plt.savefig('grid_heatmap.png', dpi=300, bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import seaborn as sns

# Create a 5x5 grid with NaN values for missing cells
grid = np.ones((5, 5))

# Set corners to NaN (missing)
grid[0, 0] = np.nan  # Top-left
grid[0, 4] = np.nan  # Top-right
grid[4, 0] = np.nan  # Bottom-left
grid[4, 4] = np.nan  # Bottom-right

# Set middle to NaN (missing)
grid[2, 2] = np.nan  # Center

data = np.loadtxt("e_f_g.csv", delimiter=",")
print(data[:,1])


# Fill the grid with example values (replace with your actual values)
# I'll use a sample where values increase from top-left to bottom-right
n = 0
for i in range(5):
    for j in range(5):
        if not np.isnan(grid[i, j]):
            grid[i, j] = data[n, 1]  # Sample values
            n += 1

# Create a custom colormap that doesn't color NaN values
cmap = plt.cm.viridis.copy()
cmap.set_bad('white', 1.0)

# Create the heatmap
plt.figure(figsize=(6, 4))
ax = sns.heatmap(grid, cmap=cmap, annot=True, fmt=".1f", linewidths=.5, 
                square=True, mask=np.isnan(grid))

# Add title and labels
plt.title('5x5 Grid Heatmap (without corners and center)', fontsize=16)
plt.xlabel('Column', fontsize=12)
plt.ylabel('Row', fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()

# If you need to save the plot
# plt.savefig('grid_heatmap.png', dpi=300, bbox_inches='tight')
# Out:
# [ 40.8  48.6  53.4  56.8  67.5  72.2  71.4  58.6  81.7 102.9  90.3  67.
#   92.  127.  135.4 115.2  72.3  99.2 114.   99. ]
