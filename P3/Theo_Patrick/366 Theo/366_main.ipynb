# %%
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⢀⡔⣻⠁⠀⢀⣀⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⢀⣾⠳⢶⣦⠤⣀⠀⠀⠀⠀⠀⠀⠀⣾⢀⡇⡴⠋⣀⠴⣊⣩⣤⠶⠞⢹⣄⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⠀⢠⠈⠙⠢⣙⠲⢤⠤⠤⠀⠒⠳⡄⣿⢀⠾⠓⢋⠅⠛⠉⠉⠝⠀⠼⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⢰⡀⠁⠀⠀⠈⠑⠦⡀⠀⠀⠀⠀⠈⠺⢿⣂⠀⠉⠐⠲⡤⣄⢉⠝⢸⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⢀⡹⠆⠀⠀⠀⠀⡠⠃⠀⠀⠀⠀⠀⠀⠀⠉⠙⠲⣄⠀⠀⠙⣷⡄⢸⠀⠀⠀
#⠀⠀⠀⠀⢸⡀⠙⠂⢠⠀⠀⡠⠊⠀⠀⠀⠀⢠⠀⠀⠀⠀⠘⠄⠀⠀⠑⢦⣔⠀⢡⡸⠀⠀⠀
#⠀⠀⠀⠀⢀⣧⠀⢀⡧⣴⠯⡀⠀⠀⠀⠀⠀⡎⠀⠀⠀⠀⠀⢸⡠⠔⠈⠁⠙⡗⡤⣷⡀⠀⠀
#⠀⠀⠀⠀⡜⠈⠚⠁⣬⠓⠒⢼⠅⠀⠀⠀⣠⡇⠀⠀⠀⠀⠀⠀⣧⠀⠀⠀⡀⢹⠀⠸⡄⠀⠀
#⠀⠀⠀⡸⠀⠀⠀⠘⢸⢀⠐⢃⠀⠀⠀⡰⠋⡇⠀⠀⠀⢠⠀⠀⡿⣆⠀⠀⣧⡈⡇⠆⢻⠀⠀
#⠀⠀⢰⠃⠀⠀⢀⡇⠼⠉⠀⢸⡤⠤⣶⡖⠒⠺⢄⡀⢀⠎⡆⣸⣥⠬⠧⢴⣿⠉⠸⡀⣇⠀
#⠀⠀⠇⠀⠀⠀⢸⠀⠀⠀⣰⠋⠀⢸⣿⣿⠀⠀⠀⠙⢧⡴⢹⣿⣿⠀⠀⠀⠈⣆⠀⠀⢧⢹⡄
#⠀⣸⠀⢠⠀⠀⢸⡀⠀⠀⢻⡀⠀⢸⣿⣿⠀⠀⠀⠀⡼⣇⢸⣿⣿⠀⠀⠀⢀⠏⠀⠀⢸⠀⠇
#⠀⠓⠈⢃⠀⠀⠀⡇⠀⠀⠀⣗⠦⣀⣿⡇⠀⣀⠤⠊⠀⠈⠺⢿⣃⣀⠤⠔⢸⠀⠀⠀⣼⠑⢼
#⠀⠀⠀⢸⡀⣀⣾⣷⡀⠀⢸⣯⣦⡀⠀⠀⠀⢇⣀⣀⠐⠦⣀⠘⠀⠀⢀⣰⣿⣄⠀⠀⡟⠀⠀
#⠀⠀⠀⠀⠛⠁⣿⣿⣧⠀⣿⣿⣿⣿⣦⣀⠀⠀⠀⠀⠀⠀⠀⣀⣠⣴⣿⣿⡿⠈⠢⣼⡇⠀⠀
#⠀⠀⠀⠀⠀⠀⠈⠁⠈⠻⠈⢻⡿⠉⣿⠿⠛⡇⠒⠒⢲⠺⢿⣿⣿⠉⠻⡿⠁⠀⠀⠈⠁⠀⠀
#⢀⠤⠒⠦⡀⠀⠀⠀⠀⠀⠀⠀⢀⠞⠉⠆⠀⠀⠉⠉⠉⠀⠀⡝⣍⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⡎⠀⠀⠀⡇⠀⠀⠀⠀⠀⠀⡰⠋⠀⠀⢸⠀⠀⠀⠀⠀⠀⠀⢡⠈⢦⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⡇⠀⠀⠸⠁⠀⠀⠀⠀⢀⠜⠁⠀⠀⠀⡸⠀⠀⠀⠀⠀⠀⠀⠘⡄⠈⢳⡀⠀⠀⠀⠀⠀⠀⠀
#⡇⠀⠀⢠⠀⠀⠀⠀⠠⣯⣀⠀⠀⠀⡰⡇⠀⠀⠀⠀⠀⠀⠀⠀⢣⠀⢀⡦⠤⢄⡀⠀⠀⠀⠀
#⢱⡀⠀⠈⠳⢤⣠⠖⠋⠛⠛⢷⣄⢠⣷⠁⠀⠀⠀⠀⠀⠀⠀⠀⠘⡾⢳⠃⠀⠘⢇⠀⠀⠀
#⠀⠙⢦⡀⠀⢠⠁⠀⠀⠀⠀⠀⠙⣿⣏⣀⠀⠀⠀⠀⠀⠀⠀⣀⣴⣧⡃⠀⠀⠀ ⠀⣸⠀⠀⠀
#⠀⠀⠀⠈⠉⢺⣄⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣗⣤⣀⣠⡾⠃⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠣⢅⡤⣀⣀⣠⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⠉⠉⠉⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⠉⠁⠀⠉⣿⣿⣿⣿⣿⡿⠻⣿⣿⣿⣿⠛⠉⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⣿⣿⣿⠀⠀⠀⠀⣿⣿⣿⡿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⣿⣿⣿⣟⠀⠀⢠⣿⣿⣿⣿⣧⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⣿⣿⣿⣿⣿⠀⠀⢸⣿⣿⣿⣿⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⡏⠀⠀⢸⣿⣿⣿⣿⣿⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⣿⣿⣿⠀⠀⠀⢺⣿⣿⣿⣿⣿⣿⣷⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⠀⠀⠀⠀⠈⠉⠻⣿⣿⣿⠟⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⢿⣿⣿⣿⠏⠀⠀⠀⠀⠀⠀⠀⠀
# 


import sys
import os
import sympy as sp
import numpy as np
import pandas as pd

# Add the correct path to the P2 folder
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

from gauss_fehlerfortpflanzung import evaluate_gaussian_error
from gauss_fehlerfortpflanzung import gaussian_error_propagation
from geraden_fit import geraden_fit
from scientific_error_rounder import runden_und_speichern
from mean_calc_w_err import err_weighted_mean
from data_handler import add_column_to_file
from tabelle import tabellen_ersteller

# %%
del_alpha = 3/60

# 366.b
var_names=[alpha_1, alpha_2]=sp.symbols('alpha_1 alpha_2')
formula=0.5 * (alpha_1 - alpha_2)
gaussian_error_propagation(formula, ((alpha_1, 54.5, del_alpha),(alpha_2,- 66 + 1/60,del_alpha)))
# Out:
# Formel: 0.5*alpha_1 - 0.5*alpha_2
# Werte: ((alpha_1, 54.5, 0.05), (alpha_2, -65.98333333333333, 0.05))
#
# Formelwert: 60.2416666666667
#
# Fehlerformel: sqrt((0.5*del_alpha_1)**2 + (-0.5*del_alpha_2)**2)
# Fehler: 0.0353553390593274
# Ergebnis: 60.24±0.04
# Das Ergebnis hat eine Genauigkeit von 0.066%

# %%
# 366.c

geraden_fit(
    exp_nr='',
    file_n='c.csv',
    title=r'Abb. 1: 366.c) Wellenlänge $\lambda$ gegen Ablenkwinkel $\delta$',
    y_label=r'Wellenlänge $\lambda$ [nm]',
    x_label=r'Ablenkwinkel $\delta$ [deg]',
    save=True,
    length=11,
    height=6,
    x_axis=0,
    y_axis=0,
    x_min=47,
    y_min=380,
    # x_major_ticks=50,   # Hauptticks alle 10 Einheiten
    # x_minor_ticks=10,    # Nebenticks alle 1 Einheit
    # y_major_ticks=0.2,
    # y_minor_ticks=0.05,
    legendlocation='best',
    y_labels=['Messung'],  # Provide labels for each dataset
    # y_markers=['o'],       # Optional: specify markers
    y_colors=['blue'], # Optional: specify colors
    x_decimal_places=0,
    y_decimal_places=1,
    plot_errors =  True,
    linear_fit=False,
    plot_y_inter=False,
    size = 1.3
)

# %%
# 366.e

var_names=[delta, lambdaa, gamma]=sp.symbols('d l g')
formula_list=[
    lambdaa**(-2),
    sp.sin((delta + gamma)/2) / sp.sin(gamma/2),
    ]
evaluate_gaussian_error('e.csv',formulas=formula_list, variables=var_names, result_length=20,result_names=['lambda^-2', 'n'], output_file_suffix= 'plot')
# Out:
# sqrt((0)**2 + (-2*del_l/l**3)**2 + (0)**2)
# sqrt((del_d*cos(d/2 + g/2)/(2*sin(g/2)))**2 + (0)**2 + (del_g*(cos(d/2 + g/2)/(2*sin(g/2)) - sin(d/2 + g/2)*cos(g/2)/(2*sin(g/2)**2)))**2)
# Zeile 1: [3.86617443791519e-06, 1.52038e-15, 0.9731770752874161, 0.015677999770667618]
# Zeile 2: [2.41604706082771e-06, 7.5108e-16, 0.5690438368032613, 0.029941856360124277]
# Zeile 3: [2.98231057157439e-06, 1.03005e-15, 0.7605544338499992, 0.025563156260853755]
# Zeile 4: [3.00405991247102e-06, 1.04134e-15, 0.7893805390369187, 0.024656700043810507]
# Zeile 5: [3.35341620073676e-06, 1.22818e-15, 0.8674491534590553, 0.021704713078091173]
# Zeile 6: [4.34045862833675e-06, 1.80856e-15, 1.028662590712108, 0.009461099910110309]
# Zeile 7: [4.56941915290617e-06, 1.95354e-15, 1.0384423399827498, 0.006595411964735377]
# Zeile 8: [5.26460458313869e-06, 2.4159e-15, 0.9787857641952384, 0.00883444568533973]
# Zeile 9: [6.10688083540097e-06, 3.01828e-15, 0.7599001818420413, 0.020286067933627683]
# Auswertung abgeschlossen. Ergebnisse wurden in 'e_plot.csv' gespeichert.

# %%
geraden_fit(
    exp_nr='',
    file_n='e_plot.csv',
    title=r'Abb. 2: 366.e) Brechungsindex $n$ gegen $\lambda^{-2}$',
    x_label=r'$\lambda^{-2} [\text{nm}^{-2}]$',
    y_label=r'Brechungsindex $n$',
    save=True,
    length=11,
    height=6,
    x_axis=0,
    y_axis=0,
    # x_min=47,
    # y_min=380,
    # x_major_ticks=50,   # Hauptticks alle 10 Einheiten
    # x_minor_ticks=10,    # Nebenticks alle 1 Einheit
    # y_major_ticks=0.2,
    # y_minor_ticks=0.05,
    legendlocation='best',
    y_labels=['Messung'],  # Provide labels for each dataset
    # y_markers=['o'],       # Optional: specify markers
    y_colors=['blue'], # Optional: specify colors
    x_decimal_places=0,
    y_decimal_places=1,
    plot_errors =  True,
    linear_fit=True,
    plot_y_inter=True,
    size = 1.3
)
# Out:
# 44492.659615255965 153746.71810115955
# Fit-Ergebnisse für Messung:
# Schwerpunkt: (0.0000045232910590 ± 0.0000000000000013, 0.979 ± 0.012)
# Steigung: 44000 ± 6000
# Y-Achsenabschnitt: 0.78 ± 0.03
