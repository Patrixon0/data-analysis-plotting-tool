# %%
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⢀⡔⣻⠁⠀⢀⣀⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⢀⣾⠳⢶⣦⠤⣀⠀⠀⠀⠀⠀⠀⠀⣾⢀⡇⡴⠋⣀⠴⣊⣩⣤⠶⠞⢹⣄⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⠀⢠⠈⠙⠢⣙⠲⢤⠤⠤⠀⠒⠳⡄⣿⢀⠾⠓⢋⠅⠛⠉⠉⠝⠀⠼⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⢰⡀⠁⠀⠀⠈⠑⠦⡀⠀⠀⠀⠀⠈⠺⢿⣂⠀⠉⠐⠲⡤⣄⢉⠝⢸⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⢀⡹⠆⠀⠀⠀⠀⡠⠃⠀⠀⠀⠀⠀⠀⠀⠉⠙⠲⣄⠀⠀⠙⣷⡄⢸⠀⠀⠀
#⠀⠀⠀⠀⢸⡀⠙⠂⢠⠀⠀⡠⠊⠀⠀⠀⠀⢠⠀⠀⠀⠀⠘⠄⠀⠀⠑⢦⣔⠀⢡⡸⠀⠀⠀
#⠀⠀⠀⠀⢀⣧⠀⢀⡧⣴⠯⡀⠀⠀⠀⠀⠀⡎⠀⠀⠀⠀⠀⢸⡠⠔⠈⠁⠙⡗⡤⣷⡀⠀⠀
#⠀⠀⠀⠀⡜⠈⠚⠁⣬⠓⠒⢼⠅⠀⠀⠀⣠⡇⠀⠀⠀⠀⠀⠀⣧⠀⠀⠀⡀⢹⠀⠸⡄⠀⠀
#⠀⠀⠀⡸⠀⠀⠀⠘⢸⢀⠐⢃⠀⠀⠀⡰⠋⡇⠀⠀⠀⢠⠀⠀⡿⣆⠀⠀⣧⡈⡇⠆⢻⠀⠀
#⠀⠀⢰⠃⠀⠀⢀⡇⠼⠉⠀⢸⡤⠤⣶⡖⠒⠺⢄⡀⢀⠎⡆⣸⣥⠬⠧⢴⣿⠉⠸⡀⣇⠀
#⠀⠀⠇⠀⠀⠀⢸⠀⠀⠀⣰⠋⠀⢸⣿⣿⠀⠀⠀⠙⢧⡴⢹⣿⣿⠀⠀⠀⠈⣆⠀⠀⢧⢹⡄
#⠀⣸⠀⢠⠀⠀⢸⡀⠀⠀⢻⡀⠀⢸⣿⣿⠀⠀⠀⠀⡼⣇⢸⣿⣿⠀⠀⠀⢀⠏⠀⠀⢸⠀⠇
#⠀⠓⠈⢃⠀⠀⠀⡇⠀⠀⠀⣗⠦⣀⣿⡇⠀⣀⠤⠊⠀⠈⠺⢿⣃⣀⠤⠔⢸⠀⠀⠀⣼⠑⢼
#⠀⠀⠀⢸⡀⣀⣾⣷⡀⠀⢸⣯⣦⡀⠀⠀⠀⢇⣀⣀⠐⠦⣀⠘⠀⠀⢀⣰⣿⣄⠀⠀⡟⠀⠀
#⠀⠀⠀⠀⠛⠁⣿⣿⣧⠀⣿⣿⣿⣿⣦⣀⠀⠀⠀⠀⠀⠀⠀⣀⣠⣴⣿⣿⡿⠈⠢⣼⡇⠀⠀
#⠀⠀⠀⠀⠀⠀⠈⠁⠈⠻⠈⢻⡿⠉⣿⠿⠛⡇⠒⠒⢲⠺⢿⣿⣿⠉⠻⡿⠁⠀⠀⠈⠁⠀⠀
#⢀⠤⠒⠦⡀⠀⠀⠀⠀⠀⠀⠀⢀⠞⠉⠆⠀⠀⠉⠉⠉⠀⠀⡝⣍⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⡎⠀⠀⠀⡇⠀⠀⠀⠀⠀⠀⡰⠋⠀⠀⢸⠀⠀⠀⠀⠀⠀⠀⢡⠈⢦⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⡇⠀⠀⠸⠁⠀⠀⠀⠀⢀⠜⠁⠀⠀⠀⡸⠀⠀⠀⠀⠀⠀⠀⠘⡄⠈⢳⡀⠀⠀⠀⠀⠀⠀⠀
#⡇⠀⠀⢠⠀⠀⠀⠀⠠⣯⣀⠀⠀⠀⡰⡇⠀⠀⠀⠀⠀⠀⠀⠀⢣⠀⢀⡦⠤⢄⡀⠀⠀⠀⠀
#⢱⡀⠀⠈⠳⢤⣠⠖⠋⠛⠛⢷⣄⢠⣷⠁⠀⠀⠀⠀⠀⠀⠀⠀⠘⡾⢳⠃⠀⠘⢇⠀⠀⠀
#⠀⠙⢦⡀⠀⢠⠁⠀⠀⠀⠀⠀⠙⣿⣏⣀⠀⠀⠀⠀⠀⠀⠀⣀⣴⣧⡃⠀⠀⠀ ⠀⣸⠀⠀⠀
#⠀⠀⠀⠈⠉⢺⣄⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣗⣤⣀⣠⡾⠃⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠣⢅⡤⣀⣀⣠⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⠉⠉⠉⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⠉⠁⠀⠉⣿⣿⣿⣿⣿⡿⠻⣿⣿⣿⣿⠛⠉⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⣿⣿⣿⠀⠀⠀⠀⣿⣿⣿⡿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⣿⣿⣿⣟⠀⠀⢠⣿⣿⣿⣿⣧⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⣿⣿⣿⣿⣿⠀⠀⢸⣿⣿⣿⣿⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⡏⠀⠀⢸⣿⣿⣿⣿⣿⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⣿⣿⣿⠀⠀⠀⢺⣿⣿⣿⣿⣿⣿⣷⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⠀⠀⠀⠀⠈⠉⠻⣿⣿⣿⠟⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⢿⣿⣿⣿⠏⠀⠀⠀⠀⠀⠀⠀⠀
# 


import sys
import os
import sympy as sp
import numpy as np
import pandas as pd

# Add the correct path to the P2 folder
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

from gauss_fehlerfortpflanzung import evaluate_gaussian_error
from gauss_fehlerfortpflanzung import gaussian_error_propagation
from geraden_fit import geraden_fit
from scientific_error_rounder import runden_und_speichern
from mean_calc_w_err import err_weighted_mean
from data_handler import add_column_to_file
from tabelle import tabellen_ersteller
from geraden_fit_config import config_1

# %%
del_alpha = 3/60

# 366.b
var_names=[alpha_1, alpha_2]=sp.symbols('alpha_1 alpha_2')
formula=0.5 * (alpha_1 - alpha_2)
gaussian_error_propagation(formula, ((alpha_1, 54.5, del_alpha),(alpha_2,- 66 + 1/60,del_alpha)))
# Out:
# Formel: 0.5*alpha_1 - 0.5*alpha_2
# Werte: ((alpha_1, 54.5, 0.05), (alpha_2, -65.98333333333333, 0.05))
#
# Formelwert: 60.2416666666667
#
# Fehlerformel: sqrt((0.5*del_alpha_1)**2 + (-0.5*del_alpha_2)**2)
# Fehler: 0.0353553390593274
# Ergebnis: 60.24±0.04
# Das Ergebnis hat eine Genauigkeit von 0.066%

# %%
def lambdaa(x):
    return 23562821779.880985/x**3 + (-1355651868.0721853)/x**2 + 26070846.7315118/x + (-167207.49255570857)

# Lampe 1:

alphas = np.array(
[47.6,
47.4,
48.1666666666667,
49.1,
49.05,
49.2333333333333,
49.6,
50.0833333333333,
50.2666666666667])

print(lambdaa(alphas))
# Out:
# [655.69711619 684.14327754 586.81217344 504.29050206 507.90343714
#  495.0403633  472.26019786 447.33396943 439.14631615]

# %%
# 366.c

# Definiere die Symbole für die Formel
x = sp.symbols('x')

# Definiere die Formel
formula = [lambdaa(x)]

# Erstelle eine angepasste Konfiguration
config = config_1
config.plot_formula = True
config.formula = formula
config.var_names = var_names
config.formula_x_range = (47, 53)

geraden_fit(
    # config,
    exp_nr='',
    file_n='c.csv',
    title=r'Abb. 1: 366.c) Wellenlänge $\lambda$ gegen Ablenkwinkel $\delta$',
    y_label=r'Wellenlänge $\lambda$ [nm]',
    x_label=r'Ablenkwinkel $\delta$ [deg]',
    save=True,
    length=11,
    height=6,
    x_axis=0,
    y_axis=0,
    x_min=47,
    x_max=52,
    y_min=380,
    x_major_ticks=1,   # Hauptticks alle 10 Einheiten
    x_minor_ticks=0.25,    # Nebenticks alle 1 Einheit
    y_major_ticks=50,
    y_minor_ticks=25,
    legendlocation='best',
    y_labels=['Messung'],  # Provide labels for each dataset
    # y_markers=['o'],       # Optional: specify markers
    y_colors=['blue'], # Optional: specify colors
    x_decimal_places=0,
    y_decimal_places=1,
    plot_errors =  True,
    linear_fit=False,
    plot_y_inter=False,
    size = 1.3
)

# %%
# Definiere die Symbole für die Formel
x = sp.symbols('x')

# Definiere die Formel
formula = [lambdaa(x)]

# Erstelle eine angepasste Konfiguration
config = config_1
config.plot_formula = True
config.formula = formula
config.var_names = var_names
config.formula_x_range = (48, 53)

# Führe geraden_fit mit der angepassten Konfiguration aus
geraden_fit('c.csv', config, plot_formula=True, title='Kalibrationskurve', y_label=r'Wellenlänge $\lambda$ [nm]', x_label=r'Ablenkwinkel $\delta$ [°]',
			 y_axis=48, x_axis=350, linear_fit=False, focus_point=False,
			y_major_ticks=50, y_minor_ticks=10, x_major_ticks=1, x_minor_ticks=0.5, save=False, )

# %%
# 366.a

var_names=[A, gamma, delta]=sp.symbols('A gamma delta')
formula=2*A/sp.cos((gamma+delta)/2)*sp.sin(gamma/2)
gaussian_error_propagation(formula, ((A,1.6e-2,0.3e-2),(gamma,60.24*sp.pi/180,0.04*sp.pi/180),(delta,49*sp.pi/180,0.05*sp.pi/180)))
# Out:
# Formel: 2*A*sin(gamma/2)/cos(delta/2 + gamma/2)
# Werte: ((A, 0.016, 0.003), (gamma, 0.334666666666667*pi, 0.000222222222222222*pi), (delta, 49*pi/180, 0.000277777777777778*pi))
#
# Formelwert: 0.0277341979909536
#
# Fehlerformel: sqrt((2*del_A*sin(gamma/2)/cos(delta/2 + gamma/2))**2 + (del_gamma*(A*sin(gamma/2)*sin(delta/2 + gamma/2)/cos(delta/2 + gamma/2)**2 + A*cos(gamma/2)/cos(delta/2 + gamma/2)))**2 + (A*del_delta*sin(gamma/2)*sin(delta/2 + gamma/2)/cos(delta/2 + gamma/2)**2)**2)
# Fehler: 0.00520027843449590
# Ergebnis: 0.028±0.005
# Das Ergebnis hat eine Genauigkeit von 17.857%

# %%
# 366.e

var_names=[delta, lambdaa, gamma]=sp.symbols('d l g')
formula_list=[
    1/(lambdaa**2),
    sp.sin((delta + gamma)*2*sp.pi/(2*360)) / sp.sin(gamma*2*sp.pi/(2*360)),
    ]
evaluate_gaussian_error('e.csv',formulas=formula_list, variables=var_names, result_length=20,result_names=['lambda^-2', 'n'], output_file_suffix= 'plot')
# Out:
# sqrt((0)**2 + (-2*del_l/l**3)**2 + (0)**2)
# sqrt((pi*del_d*cos(pi*(d/360 + g/360))/(360*sin(pi*g/360)))**2 + (0)**2 + (del_g*(pi*cos(pi*(d/360 + g/360))/(360*sin(pi*g/360)) - pi*sin(pi*(d/360 + g/360))*cos(pi*g/360)/(360*sin(pi*g/360)**2)))**2)
# Zeile 1: [3.86617443791519e-06, 1.52038e-15, 1.6247694628664733, 0.000764135922019453]
# Zeile 2: [2.41604706082771e-06, 7.5108e-16, 1.6119165305078071, 0.0007589131107445486]
# Zeile 3: [2.98231057157439e-06, 1.03005e-15, 1.6168442626359083, 0.0007608814859945964]
# Zeile 4: [3.00405991247102e-06, 1.04134e-15, 1.6176909668345734, 0.0007612239402275637]
# Zeile 5: [3.35341620073676e-06, 1.22818e-15, 1.6202259445497713, 0.0007622566987653638]
# Zeile 6: [4.34045862833675e-06, 1.80856e-15, 1.6291210223985162, 0.0007659699170245343]
# Zeile 7: [4.56941915290617e-06, 1.95354e-15, 1.6312880698313235, 0.0007668957943291517]
# Zeile 8: [5.26460458313869e-06, 2.4159e-15, 1.638744305713078, 0.0007701458911400871]
# ...

# %%
runden_und_speichern('e_plot.csv')
# Out:
# Die gerundeten Daten wurden in der CSV-Datei "e_plot_rounded.csv" gespeichert.

# %%
geraden_fit(
    exp_nr='',
    file_n='e_plot.csv',
    title=r'Abb. 2: 366.e) Brechungsindex $n$ gegen $\lambda^{-2}$',
    x_label=r'$\lambda^{-2} [\text{nm}^{-2}]$',
    y_label=r'Brechungsindex $n$',
    save=True,
    length=11,
    height=6,
    x_axis=0,
    y_axis=0,
    # x_min=47,
    y_min=1.58,
    y_max=1.65,
    x_major_ticks=1e-06,   # Hauptticks alle 10 Einheiten
    x_minor_ticks=0.5e-06,    # Nebenticks alle 1 Einheit
    y_major_ticks=0.05,
    y_minor_ticks=0.01,
    legendlocation='best',
    y_labels=['Messung'],  # Provide labels for each dataset
    # y_markers=['o'],       # Optional: specify markers
    y_colors=['blue'], # Optional: specify colors
    x_decimal_places=0,
    y_decimal_places=2,
    plot_errors =  True,
    linear_fit=True,
    plot_y_inter=True,
    size = 1.3
)
# Out:
# 9412.734802393117 9199.299870078912
# Fit-Ergebnisse für Messung:
# Schwerpunkt: (0.0000039760053733 ± 0.0000000000000013, 1.6263 ± 0.0008)
# Steigung: 9410 ± 230
# Y-Achsenabschnitt: 1.5888 ± 0.0009

# %%
# A

var_names=[m, B, lamb]=sp.symbols('m B lamb')
formula=2*m*B/lamb**3

gaussian_error_propagation(formula, ((m,9410,230),(B,28e+6,5e+6), (lamb, 400, 0)))
print('\n')
gaussian_error_propagation(formula, ((m,9410,230),(B,28e+6,5e+6), (lamb, 500, 0)))
print('\n')
gaussian_error_propagation(formula, ((m,9410,230),(B,28e+6,5e+6), (lamb, 600, 0)))
# Out:
# Formel: 2*B*m/lamb**3
# Werte: ((m, 9410, 230), (B, 28000000.0, 5000000.0), (lamb, 400, 0))
#
# Formelwert: 8233.75000000000
#
# Fehlerformel: sqrt((2*B*del_m/lamb**3)**2 + (2*del_B*m/lamb**3)**2)
# Fehler: 1484.02170137645
# Ergebnis: 8200.0±1500.0
# Das Ergebnis hat eine Genauigkeit von 18.293%
#
#
# Formel: 2*B*m/lamb**3
# Werte: ((m, 9410, 230), (B, 28000000.0, 5000000.0), (lamb, 500, 0))
#
# Formelwert: 4215.68000000000
#
# Fehlerformel: sqrt((2*B*del_m/lamb**3)**2 + (2*del_B*m/lamb**3)**2)
# Fehler: 759.819111104742
# Ergebnis: 4200.0±800.0
# Das Ergebnis hat eine Genauigkeit von 19.048%
#
#
# Formel: 2*B*m/lamb**3
# Werte: ((m, 9410, 230), (B, 28000000.0, 5000000.0), (lamb, 600, 0))
#
# Formelwert: 2439.62962962963
#
# Fehlerformel: sqrt((2*B*del_m/lamb**3)**2 + (2*del_B*m/lamb**3)**2)
# Fehler: 439.710133741170
# Ergebnis: 2400.0±400.0
# Das Ergebnis hat eine Genauigkeit von 16.667%

# %%
# delta_lambda

var_names=[m, B, lamb]=sp.symbols('m B lamb')
formula=lamb**4 / (2*m*B)

gaussian_error_propagation(formula, ((m,9410,230),(B,28e+6,5e+6), (lamb, 400, 0)))
print('\n')
gaussian_error_propagation(formula, ((m,9410,230),(B,28e+6,5e+6), (lamb, 500, 0)))
print('\n')
gaussian_error_propagation(formula, ((m,9410,230),(B,28e+6,5e+6), (lamb, 600, 0)))
# Out:
# Formel: lamb**4/(2*B*m)
# Werte: ((m, 9410, 230), (B, 28000000.0, 5000000.0), (lamb, 400, 0))
#
# Formelwert: 0.0485805374221952
#
# Fehlerformel: sqrt((-del_m*lamb**4/(2*B*m**2))**2 + (-del_B*lamb**4/(2*B**2*m))**2)
# Fehler: 0.00875598260805446
# Ergebnis: 0.049±0.009
# Das Ergebnis hat eine Genauigkeit von 18.367%
#
#
# Formel: lamb**4/(2*B*m)
# Werte: ((m, 9410, 230), (B, 28000000.0, 5000000.0), (lamb, 500, 0))
#
# Formelwert: 0.118604827690906
#
# Fehlerformel: sqrt((-del_m*lamb**4/(2*B*m**2))**2 + (-del_B*lamb**4/(2*B**2*m))**2)
# Fehler: 0.0213769106641955
# Ergebnis: 0.119±0.021
# Das Ergebnis hat eine Genauigkeit von 17.647%
#
#
# Formel: lamb**4/(2*B*m)
# Werte: ((m, 9410, 230), (B, 28000000.0, 5000000.0), (lamb, 600, 0))
#
# Formelwert: 0.245938970699863
#
# Fehlerformel: sqrt((-del_m*lamb**4/(2*B*m**2))**2 + (-del_B*lamb**4/(2*B**2*m))**2)
# Fehler: 0.0443271619532757
# Ergebnis: 0.25±0.04
# Das Ergebnis hat eine Genauigkeit von 16.0%
