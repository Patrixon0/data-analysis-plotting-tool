# %%
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⢀⡔⣻⠁⠀⢀⣀⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⢀⣾⠳⢶⣦⠤⣀⠀⠀⠀⠀⠀⠀⠀⣾⢀⡇⡴⠋⣀⠴⣊⣩⣤⠶⠞⢹⣄⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⠀⢠⠈⠙⠢⣙⠲⢤⠤⠤⠀⠒⠳⡄⣿⢀⠾⠓⢋⠅⠛⠉⠉⠝⠀⠼⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⢰⡀⠁⠀⠀⠈⠑⠦⡀⠀⠀⠀⠀⠈⠺⢿⣂⠀⠉⠐⠲⡤⣄⢉⠝⢸⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⢀⡹⠆⠀⠀⠀⠀⡠⠃⠀⠀⠀⠀⠀⠀⠀⠉⠙⠲⣄⠀⠀⠙⣷⡄⢸⠀⠀⠀
#⠀⠀⠀⠀⢸⡀⠙⠂⢠⠀⠀⡠⠊⠀⠀⠀⠀⢠⠀⠀⠀⠀⠘⠄⠀⠀⠑⢦⣔⠀⢡⡸⠀⠀⠀
#⠀⠀⠀⠀⢀⣧⠀⢀⡧⣴⠯⡀⠀⠀⠀⠀⠀⡎⠀⠀⠀⠀⠀⢸⡠⠔⠈⠁⠙⡗⡤⣷⡀⠀⠀
#⠀⠀⠀⠀⡜⠈⠚⠁⣬⠓⠒⢼⠅⠀⠀⠀⣠⡇⠀⠀⠀⠀⠀⠀⣧⠀⠀⠀⡀⢹⠀⠸⡄⠀⠀
#⠀⠀⠀⡸⠀⠀⠀⠘⢸⢀⠐⢃⠀⠀⠀⡰⠋⡇⠀⠀⠀⢠⠀⠀⡿⣆⠀⠀⣧⡈⡇⠆⢻⠀⠀
#⠀⠀⢰⠃⠀⠀⢀⡇⠼⠉⠀⢸⡤⠤⣶⡖⠒⠺⢄⡀⢀⠎⡆⣸⣥⠬⠧⢴⣿⠉⠸⡀⣇⠀
#⠀⠀⠇⠀⠀⠀⢸⠀⠀⠀⣰⠋⠀⢸⣿⣿⠀⠀⠀⠙⢧⡴⢹⣿⣿⠀⠀⠀⠈⣆⠀⠀⢧⢹⡄
#⠀⣸⠀⢠⠀⠀⢸⡀⠀⠀⢻⡀⠀⢸⣿⣿⠀⠀⠀⠀⡼⣇⢸⣿⣿⠀⠀⠀⢀⠏⠀⠀⢸⠀⠇
#⠀⠓⠈⢃⠀⠀⠀⡇⠀⠀⠀⣗⠦⣀⣿⡇⠀⣀⠤⠊⠀⠈⠺⢿⣃⣀⠤⠔⢸⠀⠀⠀⣼⠑⢼
#⠀⠀⠀⢸⡀⣀⣾⣷⡀⠀⢸⣯⣦⡀⠀⠀⠀⢇⣀⣀⠐⠦⣀⠘⠀⠀⢀⣰⣿⣄⠀⠀⡟⠀⠀
#⠀⠀⠀⠀⠛⠁⣿⣿⣧⠀⣿⣿⣿⣿⣦⣀⠀⠀⠀⠀⠀⠀⠀⣀⣠⣴⣿⣿⡿⠈⠢⣼⡇⠀⠀
#⠀⠀⠀⠀⠀⠀⠈⠁⠈⠻⠈⢻⡿⠉⣿⠿⠛⡇⠒⠒⢲⠺⢿⣿⣿⠉⠻⡿⠁⠀⠀⠈⠁⠀⠀
#⢀⠤⠒⠦⡀⠀⠀⠀⠀⠀⠀⠀⢀⠞⠉⠆⠀⠀⠉⠉⠉⠀⠀⡝⣍⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⡎⠀⠀⠀⡇⠀⠀⠀⠀⠀⠀⡰⠋⠀⠀⢸⠀⠀⠀⠀⠀⠀⠀⢡⠈⢦⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⡇⠀⠀⠸⠁⠀⠀⠀⠀⢀⠜⠁⠀⠀⠀⡸⠀⠀⠀⠀⠀⠀⠀⠘⡄⠈⢳⡀⠀⠀⠀⠀⠀⠀⠀
#⡇⠀⠀⢠⠀⠀⠀⠀⠠⣯⣀⠀⠀⠀⡰⡇⠀⠀⠀⠀⠀⠀⠀⠀⢣⠀⢀⡦⠤⢄⡀⠀⠀⠀⠀
#⢱⡀⠀⠈⠳⢤⣠⠖⠋⠛⠛⢷⣄⢠⣷⠁⠀⠀⠀⠀⠀⠀⠀⠀⠘⡾⢳⠃⠀⠘⢇⠀⠀⠀
#⠀⠙⢦⡀⠀⢠⠁⠀⠀⠀⠀⠀⠙⣿⣏⣀⠀⠀⠀⠀⠀⠀⠀⣀⣴⣧⡃⠀⠀⠀ ⠀⣸⠀⠀⠀
#⠀⠀⠀⠈⠉⢺⣄⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣗⣤⣀⣠⡾⠃⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠣⢅⡤⣀⣀⣠⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⠉⠉⠉⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⠉⠁⠀⠉⣿⣿⣿⣿⣿⡿⠻⣿⣿⣿⣿⠛⠉⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⣿⣿⣿⠀⠀⠀⠀⣿⣿⣿⡿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⣿⣿⣿⣟⠀⠀⢠⣿⣿⣿⣿⣧⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⣿⣿⣿⣿⣿⠀⠀⢸⣿⣿⣿⣿⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⡏⠀⠀⢸⣿⣿⣿⣿⣿⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⣿⣿⣿⠀⠀⠀⢺⣿⣿⣿⣿⣿⣿⣷⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⠀⠀⠀⠀⠈⠉⠻⣿⣿⣿⠟⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⢿⣿⣿⣿⠏⠀⠀⠀⠀⠀⠀⠀⠀
# 


import sys
import os
import sympy as sp
import numpy as np

# Add the correct path to the P2 folder
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

from gauss_fehlerfortpflanzung import evaluate_gaussian_error
from geraden_fit import geraden_fit
from scientific_error_rounder import runden_und_speichern
from mean_calc_w_err import err_weighted_mean
from data_handler import add_column_to_file

# %%
# err_B

# err_B l_Fe err_l_Fe d err_d
# 0.015 0.477 0.004 0.002 0.00005
#add_column_to_file('a_mess.txt', Value=0, col_name = 'Null2', col_nr = 3 , output_file_path = 'a_mess.txt')
add_column_to_file('a_mess.txt', per_cent_error_col_name_and_val= ['B', 0.03], output_file_path = 'a_w_err2.txt')
add_column_to_file('a_w_err2.txt', Value = 0.5, col_name = 'err_I', output_file_path= 'a_w_err2.txt')
add_column_to_file('a_w_err2.txt', Value=0.477, col_name='l_Fe', output_file_path = 'a_w_err2.txt')
add_column_to_file('a_w_err2.txt', Value=0.004, col_name='err_l_Fe', output_file_path = 'a_w_err2.txt')
add_column_to_file('a_w_err2.txt', Value=0.002, col_name='d', output_file_path = 'a_w_err2.txt')
add_column_to_file('a_w_err2.txt', Value=0.00005, col_name='err_d', output_file_path = 'a_for_process.txt')
# Out:
# df.haed():
#         B   B_error    I
# 0  0.0000  0.000000 -0.5
# 1 -0.0015 -0.000045 -1.0
# 2  0.0015  0.000045 -0.5
# 3  0.0015  0.000045 -0.5
# 4  0.0000  0.000000 -0.5
# df.haed():
#     ['B',  'B_error',  'I']  err_I
# 0  0.0000         0.0  -0.5    0.5
# 1 -0.0015        -0.0  -1.0    0.5
# 2  0.0015         0.0  -0.5    0.5
# 3  0.0015         0.0  -0.5    0.5
# 4  0.0000         0.0  -0.5    0.5
# df.haed():
#    ["['B',",  "'B_error',",  "'I']",  'err_I']   l_Fe
# 0     0.0000            0.0     -0.5       0.5  0.477
# 1    -0.0015           -0.0     -1.0       0.5  0.477
# 2     0.0015            0.0     -0.5       0.5  0.477
# 3     0.0015            0.0     -0.5       0.5  0.477
# 4     0.0000            0.0     -0.5       0.5  0.477
# df.haed():
#    ['["[\'B\',",',  '"\'B_error\',",',  '"\'I\']",',  "'err_I']",  'l_Fe']  \
# 0           0.0000                 0.0          -0.5          0.5    0.477
# 1          -0.0015                -0.0          -1.0          0.5    0.477
# 2           0.0015                 0.0          -0.5          0.5    0.477
# 3           0.0015                 0.0          -0.5          0.5    0.477
# 4           0.0000                 0.0          -0.5          0.5    0.477
#
#    err_l_Fe
# 0     0.004
# 1     0.004
# 2     0.004
# 3     0.004
# 4     0.004
# df.haed():
#    ['[\'["[\\\'B\\\',",  '\'"\\\'B_error\\\',  '\'"\\\'I\\\']",\','  \
# 0                0.0000                   0.0                  -0.5
# 1               -0.0015                  -0.0                  -1.0
# 2                0.0015                   0.0                  -0.5
# 3                0.0015                   0.0                  -0.5
# 4                0.0000                   0.0                  -0.5
#
#    '"\'err_I\']",',  "'l_Fe']",  'err_l_Fe']      d
# 0               0.5       0.477        0.004  0.002
# 1               0.5       0.477        0.004  0.002
# 2               0.5       0.477        0.004  0.002
# 3               0.5       0.477        0.004  0.002
# 4               0.5       0.477        0.004  0.002
# df.haed():
#    ['[\'[\\\'["[\\\\\\\  '\'\\\'"\\\\\\\'B_er  '\'\\\'"\\\\\\\'I\\\  \
# 0                0.0000                   0.0                  -0.5
# 1               -0.0015                  -0.0                  -1.0
# 2                0.0015                   0.0                  -0.5
# 3                0.0015                   0.0                  -0.5
# 4                0.0000                   0.0                  -0.5
#
#    '\'"\\\'err_I\\\']",  '"\'l_Fe\']",',  "'err_l_Fe']",   'd']    err_d
# 0                   0.5            0.477           0.004  0.002  0.00005
# 1                   0.5            0.477           0.004  0.002  0.00005
# 2                   0.5            0.477           0.004  0.002  0.00005
# 3                   0.5            0.477           0.004  0.002  0.00005
# 4                   0.5            0.477           0.004  0.002  0.00005

# %%
mu_0 = 4 * np.pi * 10**(-7)
N = 1000  # Windungszahl

var_names=[B, I, l, d]=sp.symbols('B I l d')
formula_list=[
    B/1000,
    N * I / l - (d / (mu_0 * l)) * (B/1000),  # da B in mT
    ]
evaluate_gaussian_error('a_for_process.txt',formulas=formula_list, variables=var_names, result_length=10,result_names=['H', 'B'], output_file_suffix= 'plot')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: could not convert string to float: '['[\'[\\\'[\\\\\\\'["[\\\\\\\\\\\\\\','
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 9
#       4 var_names=[B, I, l, d]=sp.symbols('B I l d')
#       5 formula_list=[
#       6     B/1000,
#       7     N * I / l - (d / (mu_0 * l)) * (B/1000),  # da B in mT
#       8     ]
# ----> 9 evaluate_gaussian_error('a_for_process.txt',formulas=formula_list, variables=var_names, result_length=10,result_names=['H', 'B'], output_file_suffix= 'plot')
#
# File c:\Users\patjs\Downloads\P2\P2\gauss_fehlerfortpflanzung.py:100, in evaluate_gaussian_error(file_path, formulas, variables, result_names, result_length, feedback, output_file_suffix)
#      97     raise ValueError("Die Anzahl der Formeln und Ergebnisnamen muss übereinstimmen.")
#      99 # Lade die Daten aus der Datei. Gehe davon aus, dass jede Variable eine Spalte für Werte und eine für Fehler hat
# --> 100 data = np.loadtxt(file_path, usecols=range(len(variables) * 2), ndmin=1)
#     102 # Initialisiere Ergebnisliste
#     103 results = []
#
# File c:\Users\patjs\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# File c:\Users\patjs\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\npyio.py:1016, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1013     data = _preprocess_comments(data, comments, encoding)
#    1015 if read_dtype_via_object_chunks is None:
# -> 1016     arr = _load_from_filelike(
#    1017         data, delimiter=delimiter, comment=comment, quote=quote,
#    1018         imaginary_unit=imaginary_unit,
#    1019         usecols=usecols, skiplines=skiplines, max_rows=max_rows,
#    1020         converters=converters, dtype=dtype,
#    1021         encoding=encoding, filelike=filelike,
#    1022         byte_converters=byte_converters)
#    1024 else:
#    1025     # This branch reads the file into chunks of object arrays and then
#    1026     # casts them to the desired actual dtype.  This ensures correct
#    1027     # string-length and datetime-unit discovery (like `arr.astype()`).
#    1028     # Due to chunking, certain error reports are less clear, currently.
#    1029     if filelike:
#
# ValueError: could not convert string '[\'[\\\'[\\\\\\\'[\\\\\\\\\\\\\\\'["[\\\\\\\\\\\\\\\\\\\\\\\\\\\\\',' to float64 at row 0, column 1.

# %%
geraden_fit(
    exp_nr='',
    file_n='a_for_process_plot.txt',
    title=r'Abb. 1: Aufgabe c) $B$ gegen $H$',
    y_label=r'$B$ [mT]',
    x_label='H [unit]',
    save=True,
    length=10,
    height=7,
    x_axis=0,
    y_axis=0,
    # x_major_ticks=100,   # Hauptticks alle 10 Einheiten
    # x_minor_ticks=20,    # Nebenticks alle 1 Einheit
    # y_major_ticks=1,
    # y_minor_ticks=0.2,
    legendlocation='best',
    # y_labels=['$R$'],  # Provide labels for each dataset
    # y_markers=['o'],       # Optional: specify markers
    y_colors=['blue'], # Optional: specify colors
    x_decimal_places=0,
    y_decimal_places=0,
    plot_errors = False,
    size = 1
)

# %% [markdown]
# # Was ist das??????
