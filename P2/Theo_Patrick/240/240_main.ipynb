# %%
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⢀⡔⣻⠁⠀⢀⣀⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⢀⣾⠳⢶⣦⠤⣀⠀⠀⠀⠀⠀⠀⠀⣾⢀⡇⡴⠋⣀⠴⣊⣩⣤⠶⠞⢹⣄⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⠀⢠⠈⠙⠢⣙⠲⢤⠤⠤⠀⠒⠳⡄⣿⢀⠾⠓⢋⠅⠛⠉⠉⠝⠀⠼⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⢰⡀⠁⠀⠀⠈⠑⠦⡀⠀⠀⠀⠀⠈⠺⢿⣂⠀⠉⠐⠲⡤⣄⢉⠝⢸⠀⠀⠀
#⠀⠀⠀⠀⢸⠀⢀⡹⠆⠀⠀⠀⠀⡠⠃⠀⠀⠀⠀⠀⠀⠀⠉⠙⠲⣄⠀⠀⠙⣷⡄⢸⠀⠀⠀
#⠀⠀⠀⠀⢸⡀⠙⠂⢠⠀⠀⡠⠊⠀⠀⠀⠀⢠⠀⠀⠀⠀⠘⠄⠀⠀⠑⢦⣔⠀⢡⡸⠀⠀⠀
#⠀⠀⠀⠀⢀⣧⠀⢀⡧⣴⠯⡀⠀⠀⠀⠀⠀⡎⠀⠀⠀⠀⠀⢸⡠⠔⠈⠁⠙⡗⡤⣷⡀⠀⠀
#⠀⠀⠀⠀⡜⠈⠚⠁⣬⠓⠒⢼⠅⠀⠀⠀⣠⡇⠀⠀⠀⠀⠀⠀⣧⠀⠀⠀⡀⢹⠀⠸⡄⠀⠀
#⠀⠀⠀⡸⠀⠀⠀⠘⢸⢀⠐⢃⠀⠀⠀⡰⠋⡇⠀⠀⠀⢠⠀⠀⡿⣆⠀⠀⣧⡈⡇⠆⢻⠀⠀
#⠀⠀⢰⠃⠀⠀⢀⡇⠼⠉⠀⢸⡤⠤⣶⡖⠒⠺⢄⡀⢀⠎⡆⣸⣥⠬⠧⢴⣿⠉⠸⡀⣇⠀
#⠀⠀⠇⠀⠀⠀⢸⠀⠀⠀⣰⠋⠀⢸⣿⣿⠀⠀⠀⠙⢧⡴⢹⣿⣿⠀⠀⠀⠈⣆⠀⠀⢧⢹⡄
#⠀⣸⠀⢠⠀⠀⢸⡀⠀⠀⢻⡀⠀⢸⣿⣿⠀⠀⠀⠀⡼⣇⢸⣿⣿⠀⠀⠀⢀⠏⠀⠀⢸⠀⠇
#⠀⠓⠈⢃⠀⠀⠀⡇⠀⠀⠀⣗⠦⣀⣿⡇⠀⣀⠤⠊⠀⠈⠺⢿⣃⣀⠤⠔⢸⠀⠀⠀⣼⠑⢼
#⠀⠀⠀⢸⡀⣀⣾⣷⡀⠀⢸⣯⣦⡀⠀⠀⠀⢇⣀⣀⠐⠦⣀⠘⠀⠀⢀⣰⣿⣄⠀⠀⡟⠀⠀
#⠀⠀⠀⠀⠛⠁⣿⣿⣧⠀⣿⣿⣿⣿⣦⣀⠀⠀⠀⠀⠀⠀⠀⣀⣠⣴⣿⣿⡿⠈⠢⣼⡇⠀⠀
#⠀⠀⠀⠀⠀⠀⠈⠁⠈⠻⠈⢻⡿⠉⣿⠿⠛⡇⠒⠒⢲⠺⢿⣿⣿⠉⠻⡿⠁⠀⠀⠈⠁⠀⠀
#⢀⠤⠒⠦⡀⠀⠀⠀⠀⠀⠀⠀⢀⠞⠉⠆⠀⠀⠉⠉⠉⠀⠀⡝⣍⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⡎⠀⠀⠀⡇⠀⠀⠀⠀⠀⠀⡰⠋⠀⠀⢸⠀⠀⠀⠀⠀⠀⠀⢡⠈⢦⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⡇⠀⠀⠸⠁⠀⠀⠀⠀⢀⠜⠁⠀⠀⠀⡸⠀⠀⠀⠀⠀⠀⠀⠘⡄⠈⢳⡀⠀⠀⠀⠀⠀⠀⠀
#⡇⠀⠀⢠⠀⠀⠀⠀⠠⣯⣀⠀⠀⠀⡰⡇⠀⠀⠀⠀⠀⠀⠀⠀⢣⠀⢀⡦⠤⢄⡀⠀⠀⠀⠀
#⢱⡀⠀⠈⠳⢤⣠⠖⠋⠛⠛⢷⣄⢠⣷⠁⠀⠀⠀⠀⠀⠀⠀⠀⠘⡾⢳⠃⠀⠘⢇⠀⠀⠀
#⠀⠙⢦⡀⠀⢠⠁⠀⠀⠀⠀⠀⠙⣿⣏⣀⠀⠀⠀⠀⠀⠀⠀⣀⣴⣧⡃⠀⠀⠀ ⠀⣸⠀⠀⠀
#⠀⠀⠀⠈⠉⢺⣄⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣗⣤⣀⣠⡾⠃⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠣⢅⡤⣀⣀⣠⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⠉⠉⠉⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⠉⠁⠀⠉⣿⣿⣿⣿⣿⡿⠻⣿⣿⣿⣿⠛⠉⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⣿⣿⣿⠀⠀⠀⠀⣿⣿⣿⡿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⣿⣿⣿⣟⠀⠀⢠⣿⣿⣿⣿⣧⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⣿⣿⣿⣿⣿⠀⠀⢸⣿⣿⣿⣿⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⡏⠀⠀⢸⣿⣿⣿⣿⣿⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⣿⣿⣿⠀⠀⠀⢺⣿⣿⣿⣿⣿⣿⣷⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⠀⠀⠀⠀⠈⠉⠻⣿⣿⣿⠟⠀⠀⠀⠀⠀⠀⠀⠀
#⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⢿⣿⣿⣿⠏⠀⠀⠀⠀⠀⠀⠀⠀
# 


import sys
import os
import sympy as sp
import numpy as np

# Add the correct path to the P2 folder
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

from gauss_fehlerfortpflanzung import evaluate_gaussian_error
from geraden_fit import geraden_fit
from scientific_error_rounder import runden_und_speichern
from mean_calc_w_err import err_weighted_mean
from data_handler import add_column_to_file

# %%
# err_B

# err_B l_Fe err_l_Fe d err_d
# 0.015 0.477 0.004 0.002 0.00005
#add_column_to_file('a_mess.txt', Value=0, col_name = 'Null2', col_nr = 3 , output_file_path = 'a_mess.txt')
add_column_to_file('a_mess.txt', Value = 0.0005, col_name = 'err_I', col_nr = 1, output_file_path= 'a_w_err2.txt')
add_column_to_file('a_w_err2.txt', per_cent_error_col_name_and_val= ['B', 0.03], output_file_path = 'a_w_err2.txt')
add_column_to_file('a_w_err2.txt', Value=0.477, col_name='l_Fe', output_file_path = 'a_w_err2.txt')
add_column_to_file('a_w_err2.txt', Value=0.004, col_name='err_l_Fe', output_file_path = 'a_w_err2.txt')
add_column_to_file('a_w_err2.txt', Value=0.002, col_name='d', output_file_path = 'a_w_err2.txt')
add_column_to_file('a_w_err2.txt', Value=0.00005, col_name='err_d', output_file_path = 'a_for_process.txt')
# Out:
# df.haed():
#         I   err_I    B
# 0  0.0000  0.0005 -0.5
# 1 -0.0015  0.0005 -1.0
# 2  0.0015  0.0005 -0.5
# 3  0.0015  0.0005 -0.5
# 4  0.0000  0.0005 -0.5
# df.haed():
#         I   err_I    B  B_error
# 0  0.0000  0.0005 -0.5   -0.015
# 1 -0.0015  0.0005 -1.0   -0.030
# 2  0.0015  0.0005 -0.5   -0.015
# 3  0.0015  0.0005 -0.5   -0.015
# 4  0.0000  0.0005 -0.5   -0.015
# df.haed():
#         I   err_I    B  B_error   l_Fe
# 0  0.0000  0.0005 -0.5   -0.015  0.477
# 1 -0.0015  0.0005 -1.0   -0.030  0.477
# 2  0.0015  0.0005 -0.5   -0.015  0.477
# 3  0.0015  0.0005 -0.5   -0.015  0.477
# 4  0.0000  0.0005 -0.5   -0.015  0.477
# df.haed():
#         I   err_I    B  B_error   l_Fe  err_l_Fe
# 0  0.0000  0.0005 -0.5   -0.015  0.477     0.004
# 1 -0.0015  0.0005 -1.0   -0.030  0.477     0.004
# 2  0.0015  0.0005 -0.5   -0.015  0.477     0.004
# 3  0.0015  0.0005 -0.5   -0.015  0.477     0.004
# 4  0.0000  0.0005 -0.5   -0.015  0.477     0.004
# df.haed():
# ...

# %%
mu_0 = 4 * np.pi * 10**(-7)
N = 1000  # Windungszahl

var_names=[I, B, l, d]=sp.symbols('B I l d')
formula_list=[
    N * I / l - (d / (mu_0 * l)) * (B/1000),  # da B in mT
    B/1000,
    ]
evaluate_gaussian_error('a_for_process.txt',formulas=formula_list, variables=var_names, result_length=10,result_names=['H', 'B'], output_file_suffix= 'plot')
# Out:
# sqrt((1000*del_B/l)**2 + (-795.774715459477*d*del_I/l)**2 + (del_l*(-1000*B/l**2 + 795.774715459477*I*d/l**2))**2 + (-795.774715459477*I*del_d/l)**2)
# sqrt((0)**2 + (del_I/1000)**2 + (0)**2 + (0)**2)
# Zeile 1: [1.6682908081, 1.0528150899, -0.0005, 1.5e-05]
# Zeile 2: [0.1919275281, 1.0661215075, -0.001, 3e-05]
# Zeile 3: [4.8129448961, 1.0534955325, -0.0005, 1.5e-05]
# Zeile 4: [4.8129448961, 1.0534955325, -0.0005, 1.5e-05]
# Zeile 5: [1.6682908081, 1.0528150899, -0.0005, 1.5e-05]
# Zeile 6: [4.8129448961, 1.0534955325, -0.0005, 1.5e-05]
# Zeile 7: [-1.47636328, 1.0527949334, -0.0005, 1.5e-05]
# Zeile 8: [3.1446540881, 1.0485496783, 0.0, 0.0]
# Zeile 9: [4.8129448961, 1.0534955325, -0.0005, 1.5e-05]
# Zeile 10: [0.0, 1.0482180294, 0.0, 0.0]
# Zeile 11: [1.6682908081, 1.0528150899, -0.0005, 1.5e-05]
# Zeile 12: [-1.47636328, 1.0527949334, -0.0005, 1.5e-05]
# Zeile 13: [-1.47636328, 1.0527949334, -0.0005, 1.5e-05]
# Zeile 14: [3.3365816162, 1.0664873854, -0.001, 3e-05]
# ...

# %%
geraden_fit(
    exp_nr='',
    file_n='a_for_process_plot.txt',
    title=r'Abb. 1: Aufgabe c) $B$ gegen $H$',
    y_label=r'$B$ [T]',
    x_label=r'$H$ [A/m]',
    save=True,
    length=10,
    height=7,
    x_axis=0,
    y_axis=0,
    #x_major_ticks=0.001,   # Hauptticks alle 10 Einheiten
    #x_minor_ticks=0.0002,    # Nebenticks alle 1 Einheit
    #y_major_ticks=1000000,
    #y_minor_ticks=200000,
    legendlocation='best',
    # y_labels=['$R$'],  # Provide labels for each dataset
    # y_markers=['o'],       # Optional: specify markers
    y_colors=['blue'], # Optional: specify colors
    x_decimal_places=0,
    y_decimal_places=1,
    plot_errors = True,
    size = 1
)

# %% [markdown]
# # Was ist das??????
